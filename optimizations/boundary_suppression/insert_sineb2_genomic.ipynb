# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_repeated/only_successful_seqs_with_results.tsv", sep="\t")

# %%
df_control = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/all_successful_control.tsv", sep="\t")

# %%
# 1. Load the data
df_sineb2 = pd.read_csv('sine_b2_insertion_results.tsv', sep='\t')

# %%
# 1. Prepare the data for plotting
# Create a DataFrame for URQ_orig
df_orig = pd.DataFrame({
    'URQ': df_sineb2[df_sineb2["n_insertions"] == 1]['URQ_orig'],
    'Category': 'URQ_orig'
})

# Create DataFrames for URQ_sine for each n_insertions (1, 2, 3)
df_sine_list = []
for n in [1, 2, 3]:
    subset = df_sineb2[df_sineb2['n_insertions'] == n].copy()
    if not subset.empty:
        temp_df = pd.DataFrame({
            'URQ': subset['URQ_sine'],
            'Category': f'URQ_sine (n={n})'
        })
        df_sine_list.append(temp_df)

# 2. Combine all parts into one plotting DataFrame
plot_df = pd.concat([df_orig] + df_sine_list, ignore_index=True)

# 3. Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='URQ', data=plot_df, palette='Set2')

# Optional: Add swarmplot to see individual points (good for small datasets)
# sns.swarmplot(x='Category', y='URQ', data=plot_df, color=".25")

plt.title('Distribution of URQ_orig and URQ_sine by Number of Insertions')
plt.ylabel('URQ Value')
plt.xlabel('')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
# plt.savefig('urq_distribution_boxplot.png')
plt.show()
# Out:
# /tmp/SLURM_2707390/ipykernel_1529979/1502238133.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='URQ', data=plot_df, palette='Set2')

# %%
df["Bbox_URQ_diff"] = df["URQ_no_bbox"] - df["URQ_init"]

# %%
df["URQ_no_homopolymers_diff"] = df["URQ_no_homopolymers"] - df["URQ_init"]

# %%
df_control["URQ_diff"].mean()
# Out:
# 0.2325672709422727

# %%
df["URQ_diff"].mean()

# %%
df["URQ_diff"].mean() / df_control["URQ_diff"].mean()

# %%
1 - (df["URQ_no_homopolymers_diff"].mean() / df["URQ_diff"].mean())

# %%
1 - (df["Bbox_URQ_diff"].mean() / df["URQ_diff"].mean())

# %%
for n in [1, 2, 3]:
    print(f"{n} x SINE B2")
    subset = df_sineb2[df_sineb2['n_insertions'] == n]
    print(subset["URQ_diff"].mean() / df["URQ_diff"].mean())
# Out:
# 1 x SINE B2
# 0.08030088787666335
# 2 x SINE B2
# 0.1481545568263963
# 3 x SINE B2
# 0.24483349251628794

# %%
# 1. Prepare the data segments
plot_data = []

# Control
plot_data.append(pd.DataFrame({'URQ_diff': df_control['URQ_diff'], 'Category': 'Control'}))

# Experimental (All)
plot_data.append(pd.DataFrame({'URQ_diff': df['URQ_diff'], 'Category': 'Experimental (All)'}))

# Bbox
plot_data.append(pd.DataFrame({'URQ_diff': df['Bbox_URQ_diff'], 'Category': 'Bbox'}))

# SINE B2 insertions (1, 2, 3)
for n in [1, 2, 3]:
    subset = df_sineb2[df_sineb2['n_insertions'] == n]
    if not subset.empty:
        plot_data.append(pd.DataFrame({
            'URQ_diff': subset['URQ_diff'], 
            'Category': f'SINE B2 (n={n})'
        }))

# 2. Combine into one DataFrame
combined_plot_df = pd.concat(plot_data, ignore_index=True)

# 3. Define the explicit order for the X-axis
category_order = [
    'Control', 
    'Experimental (All)', 
    'Bbox', 
    'SINE B2 (n=1)', 
    'SINE B2 (n=2)', 
    'SINE B2 (n=3)'
]

# 4. Generate the plot
plt.figure(figsize=(12, 7))
sns.boxplot(
    x='Category', 
    y='URQ_diff', 
    data=combined_plot_df, 
    order=category_order,  # This enforces your requested order
    palette='Set3'
)

# Formatting
plt.title('Comparison of URQ Difference (Reordered)', fontsize=14)
plt.ylabel('URQ Difference ($URQ_{sine} - URQ_{orig}$)', fontsize=12)
plt.xlabel('')
plt.xticks(rotation=30, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
# plt.savefig("URQ_comparison.svg", format="svg")
plt.show()
# Out:
# /tmp/SLURM_2707390/ipykernel_1529979/1756341728.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# 1. Prepare the data list and labels in the requested order
data_to_plot = [
    df_control["URQ_diff"].dropna(),
    df["URQ_diff"].dropna(),
    df["Bbox_URQ_diff"].dropna(),
    df_sineb2[df_sineb2['n_insertions'] == 1]["URQ_diff"].dropna(),
    df_sineb2[df_sineb2['n_insertions'] == 2]["URQ_diff"].dropna(),
    df_sineb2[df_sineb2['n_insertions'] == 3]["URQ_diff"].dropna()
]

labels = [
    "Control",
    "Experimental (All)",
    "Bbox",
    "SINE B2 (n=1)",
    "SINE B2 (n=2)",
    "SINE B2 (n=3)"
]

# 2. Plotting using the user's style
plt.figure(figsize=(10, 6))

# patch_artist=True is essential to allow color filling
bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True, 
                 medianprops=dict(color="black", linewidth=1.5),
                 boxprops=dict(linewidth=1.2))

# # 3. Set all boxes to a uniform blue color
# for patch in bp['boxes']:
#     # You can use 'blue', 'skyblue', or '#3498db' for different shades
#     patch.set_facecolor('#3498db') 

# Formatting
plt.ylabel("URQ Difference ($URQ_{sine} - URQ_{orig}$)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.xticks(rotation=25, ha='right')

plt.tight_layout()
plt.show()
# plt.savefig("URQ_comparison.svg", format="svg")
# Out:
# /tmp/SLURM_2707390/ipykernel_1529979/1347874182.py:24: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True,

# %%
df_sineb2 = df_sineb2.rename(columns={'URQ_orig': 'URQ_init'})

# %%
# Define a helper function to scale the data
def get_scaled_diff(dataframe, col_name="URQ_diff"):
    # Suppression fraction = (URQ_sine - URQ_orig) / (0 - URQ_orig)
    # Note: URQ_orig is usually negative, so -URQ_orig is positive.
    return dataframe[col_name] / (-dataframe["URQ_init"])

# 1. Prepare the scaled data list
data_to_plot = [
    get_scaled_diff(df_control).dropna(),
    get_scaled_diff(df).dropna(),
    # For Bbox, ensure you use the correct denominator if URQ_orig is different
    df["Bbox_URQ_diff"].dropna() / (-df["URQ_init"]), 
    get_scaled_diff(df_sineb2[df_sineb2['n_insertions'] == 1]).dropna(),
    get_scaled_diff(df_sineb2[df_sineb2['n_insertions'] == 2]).dropna(),
    get_scaled_diff(df_sineb2[df_sineb2['n_insertions'] == 3]).dropna()
]

labels = [
    "Control",
    "Experimental (All)",
    "Bbox",
    "SINE B2 (n=1)",
    "SINE B2 (n=2)",
    "SINE B2 (n=3)"
]

# 2. Plotting
plt.figure(figsize=(10, 6))
bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True, 
                 showfliers=False,
                 medianprops=dict(color="black", linewidth=1.5),
                 boxprops=dict(linewidth=1.2))

# # 3. Style the boxes
# for patch in bp['boxes']:
#     patch.set_facecolor('#3498db') 

# Formatting
plt.ylabel("Fraction of Boundary Suppressed\n(0 = None, 1 = Full)")
plt.axhline(y=1, color='green', linestyle='--', alpha=0.5, label='Full Suppression')
plt.axhline(y=0, color='red', linestyle='--', alpha=0.5)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.xticks(rotation=25, ha='right')

plt.tight_layout()
# plt.savefig("URQ_suppression_fraction.svg", format="svg")
plt.show()
# Out:
# /tmp/SLURM_2707390/ipykernel_1529979/4070251658.py:29: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True,

# %%
boundary_df_f0 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
boundary_df_f1 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
boundary_df_f2 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
boundary_df_f3 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold3_-0.5_genomic_windows_table_results.tsv", sep="\t")

# %%
boundary_df_f4 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold4_-0.5_genomic_windows_table_results.tsv", sep="\t")
boundary_df_f5 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold5_-0.5_genomic_windows_table_results.tsv", sep="\t")
boundary_df_f6 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold6_-0.5_genomic_windows_table_results.tsv", sep="\t")
boundary_df_f7 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/generate_genomic_boundary/results/target_-0.5/fold7_-0.5_genomic_windows_table_results.tsv", sep="\t")

# %%
boundary_df = pd.concat([boundary_df_f0, boundary_df_f1, boundary_df_f2, boundary_df_f3,
                boundary_df_f4, boundary_df_f5, boundary_df_f6, boundary_df_f7], ignore_index=True)

# %%
boundary_df = boundary_df.rename(columns={'URQ_init': 'URQ_OG'})

# %%
def get_custom_scaled_diff(df, boundary_df, col_name="URQ_diff"):
    """
    Formula: (URQ_supp - URQ_init) / (URQ_OG - URQ_init)
    Note: URQ_diff is already (URQ_supp - URQ_init)
    """
    # Merge to get URQ_OG based on genomic coordinates
    merged = df.merge(
        boundary_df[['chrom', 'centered_start', 'centered_end', 'URQ_OG']], 
        on=['chrom', 'centered_start', 'centered_end'], 
        how='left'
    )
    
    # Calculate denominator: (URQ_OG - URQ_init)
    denominator = merged["URQ_OG"] - merged["URQ_init"]
    
    # Avoid division by zero if URQ_OG and URQ_init are identical
    return (merged[col_name] / denominator).dropna()

# %%
# Apply to your dataframes
# Assuming df_control, df, and df_sineb2 all share the same coordinate columns
data_to_plot = [
    get_custom_scaled_diff(df_control, boundary_df),
    get_custom_scaled_diff(df, boundary_df),
    # Manual calculation for Bbox to handle the specific column name
    (df.merge(boundary_df, on=['chrom', 'centered_start', 'centered_end'])
       .pipe(lambda x: x["Bbox_URQ_diff"] / (x["URQ_OG"] - x["URQ_init"]))).dropna(),
    get_custom_scaled_diff(df_sineb2[df_sineb2['n_insertions'] == 1], boundary_df),
    get_custom_scaled_diff(df_sineb2[df_sineb2['n_insertions'] == 2], boundary_df),
    get_custom_scaled_diff(df_sineb2[df_sineb2['n_insertions'] == 3], boundary_df)
]

# %%
labels = [
    "Control", "Experimental (All)", "Bbox",
    "SINE B2 (n=1)", "SINE B2 (n=2)", "SINE B2 (n=3)"
]

plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

# Using plt.boxplot as in your snippet
bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True, 
                 showfliers=False,
                 medianprops=dict(color="black", linewidth=1.5),
                 boxprops=dict(linewidth=1.2))

# Color coding for visual clarity
# colors = ['#95a5a6', '#3498db', '#9b59b6', '#f1c40f', '#e67e22', '#e74c3c']
# for patch, color in zip(bp['boxes'], colors):
#     patch.set_facecolor(color)
#     patch.set_alpha(0.7)

# Formatting
plt.ylabel("Relative Boundary Suppression\n(Relative to URQ_OG)")
plt.title("Insulation Recovery Scaled to Original Baseline", fontsize=14)

# Reference lines
plt.axhline(y=1, color='green', linestyle='--', alpha=0.6, label='Flat region')
plt.axhline(y=0, color='red', linestyle='--', alpha=0.6, label='Boundary')

plt.xticks(rotation=25, ha='right')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
# Out:
# /tmp/SLURM_2707390/ipykernel_1529979/2832337991.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True,

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns

# Define our labels
labels = [
    "Control", "Experimental (All)", "Bbox (Shuffled)",
    "SINE B2 (n=1)", "SINE B2 (n=2)", "SINE B2 (n=3)"
]

# 1. Updated Color Palette:
# Gray (Control), Blue (All Exp), Light Red (Bbox), 
# and a Sequential Purple Gradient for SINE B2
colors = [
    '#bdc3c7', # Control
    '#3498db', # Experimental (All)
    '#FA5F55', # Bbox (Light Red to match your cartoon)
    '#e1bee7', # SINE B2 n=1 (Light Purple)
    '#ba68c8', # SINE B2 n=2 (Medium Purple)
    '#7b1fa2'  # SINE B2 n=3 (Deep Purple)
]

# Keep the hatch for Bbox to further distinguish 'shuffling' from 'adding'
# hatches = [None, None, '///', None, None, None]

plt.figure(figsize=(13, 6))
sns.set_style("whitegrid")

# 2. Create the boxplot
bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True, 
                 showfliers=False,
                 medianprops=dict(color="black", linewidth=1.5),
                 boxprops=dict(linewidth=1.2))

# 3. Apply the custom styling
for i, patch in enumerate(bp['boxes']):
    patch.set_facecolor(colors[i])
    patch.set_edgecolor('#2c3e50')
    # patch.set_alpha(0.9)
    # if hatches[i]:
    #     patch.set_hatch(hatches[i])

# 4. Custom Legend
legend_elements = [
    mpatches.Patch(facecolor='#bdc3c7', label='Control'),
    # mpatches.Patch(facecolor='#FA5F55', hatch='///', label='B-box Shuffling (matches cartoon)'),
    mpatches.Patch(facecolor='#ba68c8', label='SINE B2 Additions (n=1,2,3)')
]

# Formatting
plt.ylabel("Relative Boundary Suppression\n(0 = No change, 1 = Back to Flat Region)")
plt.title("Insulation Recovery: B-box Shuffling vs. SINE B2 Dosage", fontsize=14, fontweight='bold')

# Reference lines
plt.axhline(y=1, color='green', linestyle='--', alpha=0.6, label='Flat Region Level')
plt.axhline(y=0, color='red', linestyle='--', alpha=0.6, label='Boundary Level')

plt.xticks(rotation=25, ha='right')
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1))

plt.tight_layout()
plt.savefig("URQ_comparison_contextual.svg", format="svg")
plt.show()
# Out:
# /tmp/SLURM_2707390/ipykernel_1529979/1585097125.py:30: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = plt.boxplot(data_to_plot, labels=labels, patch_artist=True,
