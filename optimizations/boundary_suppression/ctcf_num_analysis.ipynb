# %%
import numpy as np
import pandas as pd

# %%
# with suppressing

# %%
fold0 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold0_with_positions_steps_results.tsv", sep="\t")

fold0["fold"] = [0 for i in range(len(fold0))]

# %%
fold1 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold1_with_positions_steps_results.tsv", sep="\t")

fold1["fold"] = [1 for i in range(len(fold1))]

# %%
fold2 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold2_with_positions_steps_results.tsv", sep="\t")

fold2["fold"] = [2 for i in range(len(fold2))]

# %%
fold3 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold3_with_positions_steps_results.tsv", sep="\t")

fold3["fold"] = [3 for i in range(len(fold3))]

# %%
fold4 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold4_with_positions_steps_results.tsv", sep="\t")

fold4["fold"] = [4 for i in range(len(fold4))]

# %%
fold5 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold5_with_positions_steps_results.tsv", sep="\t")

fold5["fold"] = [5 for i in range(len(fold5))]

# %%
fold6 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold6_with_positions_steps_results.tsv", sep="\t")

fold6["fold"] = [6 for i in range(len(fold6))]

# %%
fold7 = pd.read_csv(f"/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/fold7_with_positions_steps_results.tsv", sep="\t")

fold7["fold"] = [7 for i in range(len(fold7))]

# %%
df = pd.concat([fold0, fold1, fold2,
                fold3, fold4, fold5,
                fold6, fold7], ignore_index=True)

# %%
df["URQ_diff"] = df["URQ_result"] - df["URQ_init"]

# %%
df = df[df["num_edits"] > 0]

# %%
df = df[df['URQ_diff'] > 0.0]

# %%
len(df)
# Out:
# 352

# %%
df.to_csv("/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/suppressing_CTCFs/results_control_repeated/all_successful_control.tsv", sep='\t', index=False)

# %%
df[['init_CTCFs_num', 'CTCFs_num']]

# %%
df[df['init_CTCFs_num'] > df['CTCFs_num']]

# %%
# control (no suppressing)

# %%
control_fold0 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold0_with_positions_steps_results.tsv", sep="\t")

control_fold0["fold"] = [0 for i in range(len(control_fold0))]

# %%
control_fold1 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold1_with_positions_steps_results.tsv", sep="\t")

control_fold1["fold"] = [1 for i in range(len(control_fold1))]

# %%
control_fold2 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold2_with_positions_steps_results.tsv", sep="\t")

control_fold2["fold"] = [2 for i in range(len(control_fold2))]

# %%
control_fold3 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold3_with_positions_steps_results.tsv", sep="\t")

control_fold3["fold"] = [3 for i in range(len(control_fold3))]

# %%
control_fold4 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold4_with_positions_steps_results.tsv", sep="\t")

control_fold4["fold"] = [4 for i in range(len(control_fold4))]

# %%
control_fold5 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold5_with_positions_steps_results.tsv", sep="\t")

control_fold5["fold"] = [5 for i in range(len(control_fold5))]

# %%
control_fold6 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold6_with_positions_steps_results.tsv", sep="\t")

control_fold6["fold"] = [6 for i in range(len(control_fold6))]

# %%
control_fold7 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control_repeated/fold7_with_positions_steps_results.tsv", sep="\t")

control_fold7["fold"] = [7 for i in range(len(control_fold7))]

# %%
control_df = pd.concat([control_fold0, control_fold1, control_fold2,
                    control_fold3, control_fold4, control_fold5,
                    control_fold6, control_fold7], ignore_index=True)

# %%
control_df["URQ_diff"] = control_df["URQ_result"] - control_df["URQ_init"]

# %%
control_df = control_df[control_df['URQ_diff'] > 0.0]

# %%
df.columns

# %%
control_df.head()

# %%
import matplotlib.pyplot as plt

# %%
df["URQ_init"].mean()

# %%
# Data
data = [
    df["URQ_init"].dropna(),
    df["URQ_result"].dropna(),
    control_df["URQ_result"].dropna()
]

labels = ["initial boundary", "suppressing", "control"]

# Plot
plt.figure(figsize=(5, 5))
plt.boxplot(data, labels=labels, patch_artist=True)

plt.ylabel("URQ")
# plt.title("URQ difference comparison")
plt.grid(axis="y", linestyle="--", alpha=0.7)
# plt.savefig("urq_before_after_suppressing.svg", format="svg")

plt.show()

# %%
# Collect the data into a list
data = [
    df["init_CTCFs_num"].dropna(),
    df["CTCFs_num"].dropna(),
    control_df["CTCFs_num"].dropna()
]

# Labels for each box
labels = ["init_boundary", "suppressing", "control"]

# %%
# Create the boxplot
plt.figure(figsize=(6, 5))
plt.boxplot(data, labels=labels, patch_artist=True)

plt.ylabel("Number of CTCFs")
# plt.title("Comparison of CTCF counts")
plt.grid(axis="y", linestyle="--", alpha=0.7)
# plt.savefig("num_ctcf_before_after_suppressing.svg", format="svg")

plt.show()

# %%
control_df.columns

# %%
# Collect the data into a list
data = [
    df["GC_slice"].dropna(),
    df["GC_slice_edited"].dropna(),
    control_df["GC_slice_edited"].dropna()
]

# Labels for each box
labels = ["init_boundary", "suppressing", "control"]

# %%
# Create the boxplot
plt.figure(figsize=(6, 5))
plt.boxplot(data, labels=labels, patch_artist=True)

plt.ylabel("GC content")
# plt.title("Comparison of CTCF counts")
plt.grid(axis="y", linestyle="--", alpha=0.7)
# plt.savefig("gc_content_before_after_suppressing.svg", format="svg")

plt.show()
