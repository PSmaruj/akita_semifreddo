# %%
import torch

# %%
import sys
import os
sys.path.append(os.path.abspath("/home1/smaruj/pytorch_akita/"))

from akita_model.model import SeqNN

# %%
import ast

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = SeqNN()
model.load_state_dict(torch.load("/scratch1/smaruj/Akita_pytorch_models/finetuned/mouse_models/Hsieh2019_mESC/models/Akita_v2_mouse_Hsieh2019_mESC_model0_finetuned.pth", map_location=device))
model.eval()
# Out:
# SeqNN(
#   (stochastic_reverse_complement): StochasticReverseComplement()
#   (stochastic_shift): StochasticShift()
#   (conv_block_1): ConvBlock(
#     (conv): Conv1d(4, 128, kernel_size=(15,), stride=(1,), padding=(7,), bias=False)
#     (batch_norm): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_tower): ConvTower(
#     (conv_tower): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ReLU()
#       (5): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): ReLU()
#       (9): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): ReLU()
#       (13): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (14): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (15): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): ReLU()
#       (17): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): ReLU()
#       (21): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (22): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (23): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): ReLU()
#       (25): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (26): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (28): ReLU()
#       (29): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (30): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (32): ReLU()
#       (33): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (34): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (35): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (36): ReLU()
#       (37): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (38): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (residual1d_block1): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block2): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block3): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block4): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block5): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block6): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(13,), dilation=(13,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block7): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(21,), dilation=(21,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block8): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(34,), dilation=(34,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block9): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(55,), dilation=(55,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block10): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(89,), dilation=(89,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block11): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(145,), dilation=(145,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (conv_reduce): ConvBlockReduce(
#     (layers): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 80, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (one_to_two): OneToTwo()
#   (conv2d_block): Conv2DBlock(
#     (block): Sequential(
#       (0): ReLU()
#       (1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (symmetrize_2d): Symmetrize2D()
#   (residual2d_block1): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block2): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(2, 2), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block3): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(4, 4), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block4): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(7, 7), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block5): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(12, 12), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block6): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(21, 21), dilation=(21, 21), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(21, 21), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (squeeze_excite): SqueezeExcite(
#     (global_pool): AdaptiveAvgPool2d(output_size=1)
#     (dense1): Linear(in_features=80, out_features=10, bias=True)
#     (dense2): Linear(in_features=10, out_features=80, bias=True)
#     (norm): BatchNorm1d(80, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#   )
#   (cropping_2d): Cropping2D()
#   (upper_tri): UpperTri()
#   (final): Final(
#     (dense): Linear(in_features=80, out_features=1, bias=True)
#   )
# )

# %%
import pandas as pd

# %%
FOLD = 0

# %%
df = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/fold{FOLD}_with_positions.tsv", sep="\t")

# %%
boundary_mask_path = "/scratch1/smaruj/generate_genomic_boundary/boundary_indices.pt"

# %%
import sys
sys.path.insert(0, "/home1/smaruj/ledidi")
from ledidi import Ledidi

# %%
bin_size = 2048
cropping_applied = 64
padding_bins = 2
padding = padding_bins * bin_size

slice_0_bins = [256]
slice_0_start = (min(slice_0_bins) + cropping_applied - padding_bins) * bin_size
slice_0_end = (max(slice_0_bins) + 1 + cropping_applied + padding_bins) * bin_size

# %%
# df

# %%
c = -0.5

# %%
import numpy as np

# %%
# Helper function to set diagonal elements to a specific value
def set_diag(matrix, value, k):
    # Explicitly set the diagonal to 'value' (in this case, np.nan) for each k
    rows, cols = matrix.shape
    for i in range(rows):
        if 0 <= i + k < cols:
            matrix[i, i + k] = value


def from_upper_triu(vector_repr, matrix_len, num_diags):
    # Ensure vector_repr is a NumPy array (if it's a PyTorch tensor, convert it)
    if isinstance(vector_repr, torch.Tensor):
        vector_repr = vector_repr.detach().flatten().cpu().numpy()  # Flatten and convert to NumPy array

    # Initialize a zero matrix of shape (matrix_len, matrix_len)
    z = np.zeros((matrix_len, matrix_len))

    # Get the indices for the upper triangular matrix
    triu_tup = np.triu_indices(matrix_len, num_diags)

    # Assign the values from the vector_repr to the upper triangular part of the matrix
    z[triu_tup] = vector_repr

    # Set the diagonals specified by num_diags to np.nan
    for i in range(-num_diags + 1, num_diags):
        set_diag(z, np.nan, i)

    # Ensure the matrix is symmetric
    return z + z.T

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plot_map(matrix, vmin=-0.6, vmax=0.6, palette="RdBu_r", width=5, height=5):
    fig, axes = plt.subplots(1, 1, figsize=(width, height))

    sns.heatmap(
        matrix,
        vmin=vmin,
        vmax=vmax,
        cbar=False,
        cmap=palette,
        square=True,
        xticklabels=False,
        yticklabels=False,
        ax=axes
    )

    plt.tight_layout()
    plt.show()

# %%
def build_ctcf_input_mask(seq_len, ctcf_locs, flanking=15):
    """
    Build a boolean mask tensor indicating CTCF regions + optional flanking bases.

    Args:
        seq_len (int): total length of the sequence (number of positions).
        ctcf_locs (list of tuples): list of (start, end) positions of CTCF sites (0-based, end exclusive).
        flanking (int): number of bases to also mask on each side of the site (default 15).

    Returns:
        torch.BoolTensor: mask of shape (seq_len,) where True means "masked / not editable".
    """
    mask = torch.zeros(seq_len, dtype=torch.bool)
    
    for start, end in ctcf_locs:
        # Apply flanking region, clamp to sequence boundaries
        start_flank = max(0, start - flanking)
        end_flank = min(seq_len, end + flanking)
        
        mask[start_flank:end_flank] = True
    
    return mask

# %%
for row in df[1:2].itertuples(index=False):
    chrom, pred_start, pred_end = row.chrom, row.centered_start, row.centered_end
    
    print(f"CTCFs suppressing for genome location: {chrom}:{pred_start}-{pred_end}")
    
    ctcf_locations = ast.literal_eval(row.ctcf_motif_locs)
    
    input_mask = build_ctcf_input_mask(2048, ctcf_locations, 15).to(device=device)
    
    X = torch.load(f"/scratch1/smaruj/suppressing_CTCFs/ohe_X/fold{FOLD}/{chrom}_{pred_start}_{pred_end}_X.pt", weights_only=True, map_location=device)
    target = torch.load(f"/scratch1/smaruj/suppressing_CTCFs/targets/target_{c}/fold{FOLD}/{chrom}_{pred_start}_{pred_end}_target.pt", weights_only=True, map_location=device)
    tower_output_path = f"/scratch1/smaruj/suppressing_CTCFs/tower_outputs/fold{FOLD}/{chrom}_{pred_start}_{pred_end}_tower_out.pt"
    
    # model.eval()
    # with torch.no_grad():
    #     pred_before = model(X)
    
    # matrix_to_plot_before = from_upper_triu(pred_before[0, 0, :], matrix_len=512, num_diags=2)
    
    # print("Matrix before")
    # plot_map(matrix_to_plot_before)
    
    wrapper = Ledidi(model, 
                    input_loss=torch.nn.L1Loss(reduction='sum'), 
                    output_loss=torch.nn.L1Loss(reduction='sum'),
                    batch_size=1,
                    l=10.0, # adjusted for generating boundaries
                    max_iter=2000,
                    early_stopping_iter=2000,
                    return_history=True,
                    verbose=True,
                    bin_size=2048,
                    input_mask_slices_0=[256], # mid-bin
                    cropping_applied=64,
                    output_mask_path=boundary_mask_path,
                    use_semifreddo=True,
                    semifreddo_temp_output_path=tower_output_path,
                    punish_ctcf=False,
                    ctcf_meme_path=None,
                    suppressing_mask=input_mask
                    ).cuda()
    
    slice_0_torch = X[:, :, slice_0_start:slice_0_end]
    
    x_bar_slice_0, history = wrapper.fit_transform(X=slice_0_torch, y_bar=target)
    
    # X_new = X.clone()
    # X_new[:,:,slice_0_start:slice_0_end] = x_bar_slice_0
    
    # model.eval()
    # with torch.no_grad():
    #     pred_after = model(X_new)
    
    # matrix_to_plot_after = from_upper_triu(pred_after[0, 0, :], matrix_len=512, num_diags=2)
    
    # print("Matrix after")
    # plot_map(matrix_to_plot_after)
# Out:
# CTCFs suppressing for genome location: chr11:65677312-66988032
# Model in train mode: False
# Gradients enabled for weights - slice 0: True
# Weights shape - slice 0: torch.Size([1, 4, 2048])
# /home1/smaruj/miniconda3/envs/pytorch_hic/lib/python3.10/site-packages/torch/nn/modules/conv.py:306: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv1d(input, weight, bias, self.stride,
# Local loss applied.
# iter=I	input_loss=0.0	output_loss=2.33e+04	total_loss=2.33e+04	time=0.0
# iter=100	input_loss=368.0	output_loss=1.441e+04	total_loss=1.809e+04	time=8.026
# iter=200	input_loss=492.0	output_loss=1.08e+04	total_loss=1.572e+04	time=7.918
# iter=300	input_loss=520.0	output_loss=9.351e+03	total_loss=1.455e+04	time=7.909
# iter=400	input_loss=516.0	output_loss=8.181e+03	total_loss=1.334e+04	time=7.911
# iter=500	input_loss=512.0	output_loss=7.641e+03	total_loss=1.276e+04	time=7.914
# iter=600	input_loss=505.0	output_loss=7.385e+03	total_loss=1.244e+04	time=7.906
# iter=700	input_loss=513.0	output_loss=7.215e+03	total_loss=1.235e+04	time=7.909
# iter=800	input_loss=515.0	output_loss=6.932e+03	total_loss=1.208e+04	time=7.903
# iter=900	input_loss=529.0	output_loss=6.689e+03	total_loss=1.198e+04	time=7.908
# iter=1000	input_loss=530.0	output_loss=6.661e+03	total_loss=1.196e+04	time=7.906
# iter=1100	input_loss=516.0	output_loss=6.526e+03	total_loss=1.169e+04	time=7.915
# iter=1200	input_loss=500.0	output_loss=6.577e+03	total_loss=1.158e+04	time=7.907
# iter=1300	input_loss=501.0	output_loss=6.511e+03	total_loss=1.152e+04	time=7.907
# iter=1400	input_loss=482.0	output_loss=6.588e+03	total_loss=1.141e+04	time=7.91
# iter=1500	input_loss=479.0	output_loss=6.52e+03	total_loss=1.131e+04	time=7.901
# iter=1600	input_loss=490.0	output_loss=6.558e+03	total_loss=1.146e+04	time=7.906
# iter=1700	input_loss=495.0	output_loss=6.649e+03	total_loss=1.16e+04	time=7.907
# iter=1800	input_loss=505.0	output_loss=6.47e+03	total_loss=1.152e+04	time=7.906
# iter=1900	input_loss=515.0	output_loss=6.565e+03	total_loss=1.171e+04	time=7.909
# iter=2000	input_loss=517.0	output_loss=6.519e+03	total_loss=1.169e+04	time=7.909
# iter=F	input_loss=478.0	output_loss=6.47e+03	total_loss=1.125e+04	time=158.3
# Last iteration with update:  1487

# %%
plt.figure(figsize=(8, 8))
plt.matshow(matrix_to_plot_before.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
plt.colorbar()
# plt.savefig("map_before.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.matshow(matrix_to_plot_after.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
plt.colorbar()
# plt.savefig("map_after.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.matshow(matrix_to_plot_after-matrix_to_plot_before.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
plt.colorbar()
# plt.savefig("map_difference.svg", format='svg')
plt.show()

# %%
# df

# %%
# original DNA seq

path = "/scratch1/smaruj/generate_genomic_boundary/ohe_X/fold0/chr11_65677312_66988032_X.pt"

# Load tensor
ohe_seq = torch.load(path)

# %%
model.eval()
with torch.no_grad():
    pred_genomic = model(ohe_seq)

# %%
matrix_genomic = from_upper_triu(pred_genomic[0, 0, :], matrix_len=512, num_diags=2)

# %%
plt.figure(figsize=(8, 8))
plt.matshow(matrix_genomic.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
plt.colorbar()
# plt.savefig("map_genomic.svg", format='svg')
plt.show()

# %%
for key in history:
    print(key)
# Out:
# input_loss
# output_loss
# total_loss
# gc_content
# batch_size
# edit_positions

# %%
edit_positions = history["edit_positions"][:1988]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert your list of lists (each of length 2048) to a 2D array
edit_array = np.array(edit_positions)  # shape: (len, 2048)
input_mask_np = input_mask.detach().cpu().numpy()
input_mask = np.array(input_mask_np)  # shape: (2048,), True = no edits allowed

plt.figure(figsize=(15, 6))
plt.imshow(edit_array, aspect='auto', cmap='Greys', interpolation='none')

# Overlay red vertical lines where input_mask is True
for pos in np.where(input_mask)[0]:
    plt.axvline(x=pos, color='red', alpha=0.2, linewidth=0.5)

plt.xlabel('Sequence Position')
plt.ylabel('Iteration')
plt.title('Edit Positions Over Optimization Steps')
plt.colorbar(label='Edit (1) / No Edit (0)')
plt.tight_layout()
plt.show()

# %%
input_mask

# %%
# from pyfaidx import Fasta

# %%
# fasta_file = "/project/fudenber_735/genomes/mm10/mm10.fa"
# genome = Fasta(fasta_file)

# %%
CTCF_PWM = "/home1/smaruj/IterativeMutagenesis/MA0139.1.meme"

# %%
def read_meme_pwm_as_numpy(filename):
    pwm_list = []  # List to store PWM rows
    
    with open(filename, 'r') as file:
        in_matrix_section = False
        
        for line in file:
            line = line.strip()
            
            # Check if we are reading the PWM matrix
            if line.startswith("letter-probability matrix"):
                in_matrix_section = True  # Start reading matrix data
                continue  # Skip this header line
            
            # If we are in the matrix section, process the rows
            if in_matrix_section and line:
                pwm_row = [float(value) for value in line.split()]  # Parse values
                pwm_list.append(pwm_row)  # Append to the PWM list
            
            # If we encounter a new MOTIF or the end of file, stop matrix reading
            if line.startswith("MOTIF") and in_matrix_section:
                break
    
    # Convert the list to a numpy array
    pwm_array = np.array(pwm_list)
    
    return pwm_array

# %%
pwm_CTCF = read_meme_pwm_as_numpy(CTCF_PWM)
pwm_CTCF_tensor = torch.from_numpy(pwm_CTCF.T).float()
motifs_dict = {"CTCF": pwm_CTCF_tensor}

# %%
from memelite import fimo

# %%
320 * 2048

# %%
original_hits = fimo(
    motifs=motifs_dict,
    sequences=X[:, :, 655360:655360+2048].cpu().detach().numpy(),
    threshold=1e-4,
    reverse_complement=True
)[0]

# %%
ctcf_locations
# Out:
# [(709, 728), (1349, 1368), (1400, 1419), (1487, 1506)]

# %%
original_hits

# %%
updated_hits = fimo(
    motifs=motifs_dict,
    sequences=x_bar_slice_0[:, :, 4096:-4096].cpu().detach().numpy(),
    threshold=1e-4,
    reverse_complement=True
)[0]

# %%
updated_hits
# Out:
#   motif_name  motif_idx  sequence_name  start   end strand      score  \
# 0       CTCF          0              0    709   728      +  13.861783
# 1       CTCF          0              0   1163  1182      +  12.705756
# 2       CTCF          0              0   1349  1368      +  15.472153
# 3       CTCF          0              0   1400  1419      +  21.300177
# 4       CTCF          0              0   1487  1506      +  19.513867
# 5       CTCF          0              0   1107  1126      -  19.810905
# 6       CTCF          0              0   1582  1601      -  21.748005
#
#         p-value
# 0  7.224040e-06
# 1  1.304176e-05
# 2  2.866876e-06
# 3  3.431705e-08
# 4  1.669396e-07
# 5  1.304470e-07
# 6  2.316665e-08

# %%
edit_array = np.array(edit_positions)  # shape: (2763, 2048)

plt.figure(figsize=(15, 6))
plt.imshow(edit_array, aspect='auto', cmap='Greys', interpolation='none')

plotting_flank = 15

# Plot vertical shaded regions for CTCF motif positions
for _, row in original_hits.iterrows():
    start = row['start']
    end = row['end']
    plt.axvspan(start-plotting_flank, end+plotting_flank , color='red', alpha=0.3)

plt.xlabel('Sequence Position')
plt.ylabel('Iteration')
plt.title('Edit Positions Over Time with CTCF Motifs')
plt.colorbar(label='Edit (1) / No Edit (0)')

plt.tight_layout()
plt.show()

# %%
# Convert to sets of (start, end) for comparison
original_coords = set(zip(original_hits["start"], original_hits["end"]))
updated_coords = set(zip(updated_hits["start"], updated_hits["end"]))

# Identify new hits in updated_hits
new_coords = updated_coords - original_coords
new_hits = updated_hits[updated_hits.apply(lambda r: (r["start"], r["end"]) in new_coords, axis=1)]

# %%
new_hits.sort_values(by="start")

# %%
edit_array[:1487,:].shape
# Out:
# (1487, 2048)

# %%
# Plot the edit array
plt.figure(figsize=(15, 6))
plt.imshow(edit_array[:1487,:], aspect="auto", cmap="Greys", interpolation="none")

plotting_flank = 15

# Plot red spans = original hits
for _, row in original_hits.iterrows():
    start, end = row["start"], row["end"]
    plt.axvspan(start - plotting_flank, end + plotting_flank, color="red", alpha=0.3)

for _, row in original_hits.iterrows():
    start, end = row["start"], row["end"]
    plt.axvspan(start, end, color="red", alpha=0.3)

# Plot green spans = new hits only in updated_hits
for _, row in new_hits.iterrows():
    start, end = row["start"], row["end"]
    plt.axvspan(start, end, color="green", alpha=0.5)

plt.xlabel("Sequence Position")
plt.ylabel("Iteration")
plt.title("Edit Positions Over Time with CTCF Motifs")
# plt.colorbar(label="Edit (1) / No Edit (0)")

plt.tight_layout()
# plt.savefig("edit_matrix_old_and_new_ctcfs.svg", format="svg")
plt.show()
