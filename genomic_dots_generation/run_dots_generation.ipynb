# %%
import torch

# %%
import sys
import os
sys.path.append(os.path.abspath("/home1/smaruj/pytorch_akita/"))

from model_v2_compatible import SeqNN

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = SeqNN()
model.load_state_dict(torch.load("/home1/smaruj/pytorch_akita/model_0_v2_finetuned_correctly.pt", map_location=device))
model.eval()
# Out:
# /tmp/SLURM_1061221/ipykernel_193166/2744654124.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/home1/smaruj/pytorch_akita/model_0_v2_finetuned_correctly.pt", map_location=device))
# SeqNN(
#   (stochastic_reverse_complement): StochasticReverseComplement()
#   (stochastic_shift): StochasticShift()
#   (conv_block_1): ConvBlock(
#     (conv): Conv1d(4, 128, kernel_size=(15,), stride=(1,), padding=(7,), bias=False)
#     (batch_norm): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_tower): ConvTower(
#     (conv_tower): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ReLU()
#       (5): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): ReLU()
#       (9): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): ReLU()
#       (13): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (14): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (15): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): ReLU()
#       (17): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): ReLU()
#       (21): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (22): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (23): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): ReLU()
#       (25): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (26): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (28): ReLU()
#       (29): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (30): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (32): ReLU()
#       (33): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (34): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (35): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (36): ReLU()
#       (37): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (38): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (residual1d_block1): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block2): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block3): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block4): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block5): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block6): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(13,), dilation=(13,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block7): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(21,), dilation=(21,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block8): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(34,), dilation=(34,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block9): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(55,), dilation=(55,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block10): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(89,), dilation=(89,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block11): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(145,), dilation=(145,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (conv_reduce): ConvBlockReduce(
#     (layers): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 80, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (one_to_two): OneToTwo()
#   (conv2d_block): Conv2DBlock(
#     (block): Sequential(
#       (0): ReLU()
#       (1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (symmetrize_2d): Symmetrize2D()
#   (residual2d_block1): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block2): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(2, 2), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block3): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(4, 4), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block4): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(7, 7), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block5): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(12, 12), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block6): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(21, 21), dilation=(21, 21), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(21, 21), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (squeeze_excite): SqueezeExcite(
#     (global_pool): AdaptiveAvgPool2d(output_size=1)
#     (dense1): Linear(in_features=80, out_features=10, bias=True)
#     (dense2): Linear(in_features=10, out_features=80, bias=True)
#     (norm): BatchNorm1d(80, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#   )
#   (cropping_2d): Cropping2D()
#   (upper_tri): UpperTri()
#   (final): Final(
#     (dense): Linear(in_features=80, out_features=1, bias=True)
#   )
# )

# %%
import pandas as pd

# %%
df = pd.read_csv("/scratch1/smaruj/genomic_insertion_loci/fold1_selected_genomic_windows_centered.tsv", sep="\t")

# %%
dots_mask_path = "/scratch1/smaruj/generate_genomic_dots/dots_indices.pt"

# %%
import sys
sys.path.insert(0, "/home1/smaruj/ledidi")
from ledidi import Ledidi

# %%
bin_size = 2048
cropping_applied = 64
padding_bins = 2
padding = padding_bins * bin_size

slice_0_bins = [256-25]
slice_0_start = (min(slice_0_bins) + cropping_applied - padding_bins) * bin_size
slice_0_end = (max(slice_0_bins) + 1 + cropping_applied + padding_bins) * bin_size

# %%
slice_1_bins =[256+25]
slice_1_start = (min(slice_1_bins) + cropping_applied - padding_bins) * bin_size
slice_1_end = (max(slice_1_bins) + 1 + cropping_applied + padding_bins) * bin_size

# %%
for row in df[:2].itertuples(index=False):
    chrom, pred_start, pred_end = row.chrom, row.centered_start, row.centered_end
    
    print(f"Dots generation for genome location: {chrom}:{pred_start}-{pred_end}")
    
    X = torch.load(f"/scratch1/smaruj/genomic_insertion_loci/ohe_X/fold1/{chrom}_{pred_start}_{pred_end}_X.pt", weights_only=True, map_location=device)
    target = torch.load(f"/scratch1/smaruj/generate_genomic_dots/targets_0.5/fold1/{chrom}_{pred_start}_{pred_end}_target.pt", weights_only=True, map_location=device)
    tower_output_path = f"/scratch1/smaruj/genomic_insertion_loci/tower_outputs/fold1/{chrom}_{pred_start}_{pred_end}_tower_out.pt"
    
    wrapper = Ledidi(model, 
                 input_loss=torch.nn.L1Loss(reduction='sum'), 
                 output_loss=torch.nn.L1Loss(reduction='sum'),
                 batch_size=1,
                 max_iter=3000,
                 early_stopping_iter=2000,
                 return_history=False,
                 verbose=True,
                 bin_size=2048,
                 input_mask_slices_0=[256-25],
                 input_mask_slices_1=[256+25],
                 cropping_applied=64,
                 output_mask_path=dots_mask_path,
                 use_semifreddo=True,
                 semifreddo_temp_output_path=tower_output_path,
                 punish_ctcf=False,
                 ctcf_meme_path=None
                 ).cuda()
    
    slice_0_torch = X[:, :, slice_0_start:slice_0_end]
    slice_1_torch = X[:, :, slice_1_start:slice_1_end]
    
    x_bar_slice_0, x_bar_slice_1, last_update = wrapper.fit_transform(X=slice_0_torch, y_bar=target, X1=slice_1_torch)
    
    torch.save(x_bar_slice_0[:,:,padding:-padding], f"/scratch1/smaruj/generate_genomic_dots/results_0.5/fold1/{chrom}_{pred_start}_{pred_end}_slice0.pt")
    torch.save(x_bar_slice_1[:,:,padding:-padding], f"/scratch1/smaruj/generate_genomic_dots/results_0.5/fold1/{chrom}_{pred_start}_{pred_end}_slice1.pt")
# Out:
# Dots generation for genome location: chr1:50487296-51798016
# Model in train mode: False
# Gradients enabled for weights - slice 0: True
# Weights shape - slice 0: torch.Size([1, 4, 2048])
# Gradients enabled for weights - slice 1: True
# Weights shape - slice 1: torch.Size([1, 4, 2048])
# Local loss applied.
# iter=I	input_loss=0.0	output_loss=6.513e+04	total_loss=6.513e+04	time=0.0
# iter=100	input_loss=803.0	output_loss=3.738e+03	total_loss=3.818e+03	time=9.817
# iter=200	input_loss=774.0	output_loss=3.197e+03	total_loss=3.275e+03	time=9.68
# iter=300	input_loss=754.0	output_loss=3.1e+03	total_loss=3.176e+03	time=9.658
# iter=400	input_loss=781.0	output_loss=2.98e+03	total_loss=3.058e+03	time=9.728
# iter=500	input_loss=807.0	output_loss=3.077e+03	total_loss=3.158e+03	time=9.716
# iter=600	input_loss=855.0	output_loss=2.988e+03	total_loss=3.073e+03	time=9.71
# iter=700	input_loss=881.0	output_loss=2.875e+03	total_loss=2.963e+03	time=9.75
# iter=800	input_loss=907.0	output_loss=2.856e+03	total_loss=2.947e+03	time=9.695
# iter=900	input_loss=943.0	output_loss=2.809e+03	total_loss=2.904e+03	time=9.675
# iter=1000	input_loss=958.0	output_loss=2.859e+03	total_loss=2.955e+03	time=9.716
# iter=1100	input_loss=955.0	output_loss=2.775e+03	total_loss=2.87e+03	time=9.691
# iter=1200	input_loss=956.0	output_loss=2.789e+03	total_loss=2.885e+03	time=9.697
# iter=1300	input_loss=972.0	output_loss=2.753e+03	total_loss=2.85e+03	time=9.714
# iter=1400	input_loss=988.0	output_loss=2.735e+03	total_loss=2.834e+03	time=9.673
# iter=1500	input_loss=962.0	output_loss=2.798e+03	total_loss=2.895e+03	time=9.698
# iter=1600	input_loss=950.0	output_loss=2.817e+03	total_loss=2.912e+03	time=9.748
# iter=1700	input_loss=970.0	output_loss=2.742e+03	total_loss=2.839e+03	time=9.706
# iter=1800	input_loss=995.0	output_loss=2.831e+03	total_loss=2.931e+03	time=9.711
# iter=1900	input_loss=984.0	output_loss=2.92e+03	total_loss=3.019e+03	time=9.705
# iter=2000	input_loss=1.016e+03	output_loss=2.899e+03	total_loss=3.001e+03	time=9.718
# iter=2100	input_loss=995.0	output_loss=2.772e+03	total_loss=2.871e+03	time=9.725
# iter=2200	input_loss=1.017e+03	output_loss=2.913e+03	total_loss=3.015e+03	time=9.746
# iter=2300	input_loss=1.007e+03	output_loss=2.75e+03	total_loss=2.851e+03	time=9.721
# iter=2400	input_loss=1.024e+03	output_loss=5.524e+03	total_loss=5.627e+03	time=9.765
# iter=2500	input_loss=999.0	output_loss=2.718e+03	total_loss=2.818e+03	time=9.718
# iter=2600	input_loss=984.0	output_loss=2.751e+03	total_loss=2.85e+03	time=9.726
# iter=2700	input_loss=990.0	output_loss=2.788e+03	total_loss=2.887e+03	time=9.737
# iter=2800	input_loss=992.0	output_loss=2.73e+03	total_loss=2.829e+03	time=9.715
# iter=2900	input_loss=989.0	output_loss=2.779e+03	total_loss=2.878e+03	time=9.704
# iter=3000	input_loss=985.0	output_loss=2.752e+03	total_loss=2.851e+03	time=9.719
# iter=F	input_loss=993.0	output_loss=2.667e+03	total_loss=2.766e+03	time=291.5
# Last iteration with update:  2674
# Dots generation for genome location: chr1:54919168-56229888
# Model in train mode: False
# Gradients enabled for weights - slice 0: True
# Weights shape - slice 0: torch.Size([1, 4, 2048])
# Gradients enabled for weights - slice 1: True
# Weights shape - slice 1: torch.Size([1, 4, 2048])
# Local loss applied.
# iter=I	input_loss=0.0	output_loss=6.55e+04	total_loss=6.55e+04	time=0.0
# iter=100	input_loss=1.096e+03	output_loss=1.263e+04	total_loss=1.274e+04	time=8.163
# iter=200	input_loss=1.108e+03	output_loss=1.023e+04	total_loss=1.035e+04	time=8.167
# iter=300	input_loss=1.079e+03	output_loss=1.004e+04	total_loss=1.015e+04	time=8.165
# iter=400	input_loss=1.139e+03	output_loss=1.006e+04	total_loss=1.017e+04	time=8.164
# iter=500	input_loss=1.157e+03	output_loss=9.769e+03	total_loss=9.885e+03	time=8.166
# iter=600	input_loss=1.132e+03	output_loss=9.755e+03	total_loss=9.868e+03	time=8.166
# iter=700	input_loss=1.145e+03	output_loss=9.636e+03	total_loss=9.75e+03	time=8.171
# iter=800	input_loss=1.156e+03	output_loss=9.882e+03	total_loss=9.997e+03	time=8.169
# iter=900	input_loss=1.135e+03	output_loss=9.715e+03	total_loss=9.828e+03	time=8.16
# iter=1000	input_loss=1.136e+03	output_loss=9.918e+03	total_loss=1.003e+04	time=8.167
# iter=1100	input_loss=1.143e+03	output_loss=9.928e+03	total_loss=1.004e+04	time=8.163
# iter=1200	input_loss=1.132e+03	output_loss=9.966e+03	total_loss=1.008e+04	time=8.168
# iter=1300	input_loss=1.139e+03	output_loss=9.83e+03	total_loss=9.944e+03	time=8.168
# iter=1400	input_loss=1.145e+03	output_loss=9.713e+03	total_loss=9.827e+03	time= 8.2
# iter=1500	input_loss=1.154e+03	output_loss=9.617e+03	total_loss=9.732e+03	time=8.167
# iter=1600	input_loss=1.125e+03	output_loss=9.641e+03	total_loss=9.753e+03	time=8.167
# iter=1700	input_loss=1.136e+03	output_loss=9.704e+03	total_loss=9.817e+03	time=8.157
# iter=1800	input_loss=1.201e+03	output_loss=9.646e+03	total_loss=9.766e+03	time=8.165
# iter=1900	input_loss=1.206e+03	output_loss=9.902e+03	total_loss=1.002e+04	time=8.158
# iter=2000	input_loss=1.187e+03	output_loss=9.552e+03	total_loss=9.67e+03	time=8.16
# iter=2100	input_loss=1.167e+03	output_loss=9.53e+03	total_loss=9.646e+03	time=8.16
# iter=2200	input_loss=1.206e+03	output_loss=9.603e+03	total_loss=9.723e+03	time=8.161
# iter=2300	input_loss=1.225e+03	output_loss=9.464e+03	total_loss=9.587e+03	time=8.159
# iter=2400	input_loss=1.201e+03	output_loss=9.436e+03	total_loss=9.556e+03	time=8.157
# iter=2500	input_loss=1.19e+03	output_loss=9.547e+03	total_loss=9.666e+03	time=8.157
# iter=2600	input_loss=1.21e+03	output_loss=9.657e+03	total_loss=9.778e+03	time=8.159
# iter=2700	input_loss=1.188e+03	output_loss=9.687e+03	total_loss=9.806e+03	time=8.159
# iter=2800	input_loss=1.225e+03	output_loss=9.753e+03	total_loss=9.875e+03	time=8.165
# iter=2900	input_loss=1.256e+03	output_loss=1.001e+04	total_loss=1.014e+04	time=8.161
# iter=3000	input_loss=1.265e+03	output_loss=9.779e+03	total_loss=9.906e+03	time=8.162
# iter=F	input_loss=1.225e+03	output_loss=9.367e+03	total_loss=9.49e+03	time=244.9
# Last iteration with update:  2224
