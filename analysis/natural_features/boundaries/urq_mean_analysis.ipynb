# %%
import pandas as pd
import numpy as np
import random

# %%
results_path = "/scratch1/smaruj/natural_boundaries_URQmean/all_boundaries_URQ_mean.tsv"
df = pd.read_csv(results_path, sep="\t")

# %%
df
# Out:
#       chrom     start       end region  is_bad_bin  \
# 0      chr1   4400000   4410000   chr1       False
# 1      chr1   4770000   4780000   chr1       False
# 2      chr1   5150000   5160000   chr1       False
# 3      chr1   5900000   5910000   chr1       False
# 4      chr1   6190000   6200000   chr1       False
# ...     ...       ...       ...    ...         ...
# 4469  chr19  57360000  57370000  chr19       False
# 4470  chr19  57660000  57670000  chr19       False
# 4471  chr19  58670000  58680000  chr19       False
# 4472  chr19  59380000  59390000  chr19       False
# 4473  chr19  59770000  59780000  chr19        True
#
#       log2_insulation_score_200000  n_valid_pixels_200000  \
# 0                        -0.425816                  358.0
# 1                        -0.489156                  397.0
# 2                        -0.231962                  377.0
# 3                        -0.404405                  397.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['URQ_mean'].plot.hist(bins=50, edgecolor='black')
plt.xlabel('URQ_mean')
plt.ylabel('Frequency')
plt.title('Distribution of URQ_mean')
plt.tight_layout()
plt.show()
