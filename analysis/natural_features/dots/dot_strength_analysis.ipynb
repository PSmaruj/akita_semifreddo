# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_path = "/project2/fudenber_735/smaruj/sequence_design/ledidi_semifreddo_akita/analysis/natural_features/dots/mouse_convergent_dots_strength.tsv"
df = pd.read_csv(results_path, sep="\t")

# %%
df['dot_strength'].plot.hist(bins=50, edgecolor='black')
plt.xlabel('dot_strength')
plt.ylabel('Frequency')
plt.title('Distribution of dot_strength')
plt.tight_layout()
plt.show()
