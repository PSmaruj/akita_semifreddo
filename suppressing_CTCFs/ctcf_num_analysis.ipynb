# %%
import numpy as np
import pandas as pd

# %%
# with suppressing

# %%
fold0 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold0_with_positions_steps_results.tsv", sep="\t")

fold0["fold"] = [0 for i in range(len(fold0))]

# %%
fold1 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold1_with_positions_steps_results.tsv", sep="\t")

fold1["fold"] = [1 for i in range(len(fold1))]

# %%
fold2 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold2_with_positions_steps_results.tsv", sep="\t")

fold2["fold"] = [2 for i in range(len(fold2))]

# %%
fold3 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold3_with_positions_steps_results.tsv", sep="\t")

fold3["fold"] = [3 for i in range(len(fold3))]

# %%
fold4 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold4_with_positions_steps_results.tsv", sep="\t")

fold4["fold"] = [4 for i in range(len(fold4))]

# %%
fold5 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold5_with_positions_steps_results.tsv", sep="\t")

fold5["fold"] = [5 for i in range(len(fold5))]

# %%
fold6 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold6_with_positions_steps_results.tsv", sep="\t")

fold6["fold"] = [6 for i in range(len(fold6))]

# %%
fold7 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results/fold7_with_positions_steps_results.tsv", sep="\t")

fold7["fold"] = [7 for i in range(len(fold7))]

# %%
df = pd.concat([fold0, fold1, fold2,
                fold3, fold4, fold5,
                fold6, fold7], ignore_index=True)

# %%
df["URQ_diff"] = df["URQ_result"] - df["URQ_init"]

# %%
df = df[df["num_edits"] > 0]

# %%
df = df[df['URQ_diff'] > 0.0]

# %%
len(df)
# Out:
# 350

# %%
df[['init_CTCFs_num', 'CTCFs_num']]
# Out:
#      init_CTCFs_num  CTCFs_num
# 0                 3          6
# 1                 4          8
# 2                 2          7
# 3                 4          6
# 4                 3          9
# ..              ...        ...
# 400               1          2
# 401               2          8
# 402               1          2
# 403               4          6
# 405               3          7
#
# [350 rows x 2 columns]

# %%
df[df['init_CTCFs_num'] > df['CTCFs_num']]
# Out:
# Empty DataFrame
# Columns: [chrom, fold, PearsonR, centered_start, centered_end, centered_flat_start, centered_flat_end, active_fraction, neutral_fraction, repressive_fraction, ctcf_motif_locs, last_accepted_step, SCD, URQ_result, URQ_target, URQ_init, num_edits, GC_seq, GC_slice, GC_slice_edited, init_CTCFs_num, CTCFs_num, avg_orig_fimo_scores, avg_new_fimo_scores, orig_CTCFs_coord, new_CTCFs_coord, avg_orig_left_fimo_scores, avg_new_left_fimo_scores, avg_orig_right_fimo_scores, avg_new_right_fimo_scores, URQ_diff]
# Index: []
#
# [0 rows x 31 columns]

# %%
# control (no suppressing)

# %%
control_fold0 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold0_with_positions_steps_results.tsv", sep="\t")

control_fold0["fold"] = [0 for i in range(len(control_fold0))]

# %%
control_fold1 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold1_with_positions_steps_results.tsv", sep="\t")

control_fold1["fold"] = [1 for i in range(len(control_fold1))]

# %%
control_fold2 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold2_with_positions_steps_results.tsv", sep="\t")

control_fold2["fold"] = [2 for i in range(len(control_fold2))]

# %%
control_fold3 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold3_with_positions_steps_results.tsv", sep="\t")

control_fold3["fold"] = [3 for i in range(len(control_fold3))]

# %%
control_fold4 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold4_with_positions_steps_results.tsv", sep="\t")

control_fold4["fold"] = [4 for i in range(len(control_fold4))]

# %%
control_fold5 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold5_with_positions_steps_results.tsv", sep="\t")

control_fold5["fold"] = [5 for i in range(len(control_fold5))]

# %%
control_fold6 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold6_with_positions_steps_results.tsv", sep="\t")

control_fold6["fold"] = [6 for i in range(len(control_fold6))]

# %%
control_fold7 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/results_control/fold7_with_positions_steps_results.tsv", sep="\t")

control_fold7["fold"] = [7 for i in range(len(control_fold7))]

# %%
control_df = pd.concat([control_fold0, control_fold1, control_fold2,
                    control_fold3, control_fold4, control_fold5,
                    control_fold6, control_fold7], ignore_index=True)

# %%
control_df["URQ_diff"] = control_df["URQ_result"] - control_df["URQ_init"]

# %%
control_df = control_df[control_df['URQ_diff'] > 0.0]

# %%
df.columns
# Out:
# Index(['chrom', 'fold', 'PearsonR', 'centered_start', 'centered_end',
#        'centered_flat_start', 'centered_flat_end', 'active_fraction',
#        'neutral_fraction', 'repressive_fraction', 'ctcf_motif_locs',
#        'last_accepted_step', 'SCD', 'URQ_result', 'URQ_target', 'URQ_init',
#        'num_edits', 'GC_seq', 'GC_slice', 'GC_slice_edited', 'init_CTCFs_num',
#        'CTCFs_num', 'avg_orig_fimo_scores', 'avg_new_fimo_scores',
#        'orig_CTCFs_coord', 'new_CTCFs_coord', 'avg_orig_left_fimo_scores',
#        'avg_new_left_fimo_scores', 'avg_orig_right_fimo_scores',
#        'avg_new_right_fimo_scores', 'URQ_diff'],
#       dtype='object')

# %%
control_df.head()
# Out:
#    chrom  fold  PearsonR  centered_start  centered_end  centered_flat_start  \
# 0   chr1     0  0.861165        37799936      39110656                  192
# 1  chr11     0  0.746112        65677312      66988032                  195
# 2   chr3     0  0.670098        38524928      39835648                  144
# 3   chr3     0  0.672787        53286912      54597632                  187
# 4   chr3     0  0.676442       119885824     121196544                  154
#
#    centered_flat_end  active_fraction  neutral_fraction  repressive_fraction  \
# 0                320         0.391304          0.521739             0.086957
# 1                317         0.333333          0.533333             0.133333
# 2                368         0.483871          0.516129             0.000000
# 3                325         0.360000          0.520000             0.120000
# 4                358         0.500000          0.500000             0.000000
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Data
data = [
    df["URQ_init"].dropna(),
    df["URQ_diff"].dropna(),
    control_df["URQ_diff"].dropna()
]

labels = ["initial boundary", "suppressing", "control"]

# Plot
plt.figure(figsize=(5, 5))
plt.boxplot(data, labels=labels, patch_artist=True)

plt.ylabel("URQ difference")
plt.title("URQ difference comparison")
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()
# Out:
# /tmp/SLURM_1840087/ipykernel_3752921/3977362595.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels, patch_artist=True)

# %%
# Collect the data into a list
data = [
    df["init_CTCFs_num"].dropna(),
    df["CTCFs_num"].dropna(),
    control_df["CTCFs_num"].dropna()
]

# Labels for each box
labels = ["init_boundary", "suppressing", "control"]

# %%
# Create the boxplot
plt.figure(figsize=(6, 5))
plt.boxplot(data, labels=labels, patch_artist=True)

plt.ylabel("Number of CTCFs")
# plt.title("Comparison of CTCF counts")
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.show()
# Out:
# /tmp/SLURM_1840087/ipykernel_3752921/1619834502.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels, patch_artist=True)
