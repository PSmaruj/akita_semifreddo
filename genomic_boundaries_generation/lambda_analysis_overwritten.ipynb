# %%
import numpy as np
import pandas as pd

# %%
l01_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_0.1/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
l01_fold0["fold"] = [0 for i in range(len(l01_fold0))]
l01_fold0["lambda"] = [0.1 for i in range(len(l01_fold0))]

# %%
l01_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_0.1/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
l01_fold1["fold"] = [1 for i in range(len(l01_fold1))]
l01_fold1["lambda"] = [0.1 for i in range(len(l01_fold1))]

# %%
l01_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_0.1/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
l01_fold2["fold"] = [2 for i in range(len(l01_fold2))]
l01_fold2["lambda"] = [0.1 for i in range(len(l01_fold2))]

# %%
l1_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_1.0/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
l1_fold0["fold"] = [0 for i in range(len(l1_fold0))]
l1_fold0["lambda"] = [1.0 for i in range(len(l1_fold0))]

# %%
l1_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_1.0/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
l1_fold1["fold"] = [1 for i in range(len(l1_fold1))]
l1_fold1["lambda"] = [1.0 for i in range(len(l1_fold1))]

# %%
l1_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_1.0/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
l1_fold2["fold"] = [2 for i in range(len(l1_fold2))]
l1_fold2["lambda"] = [1.0 for i in range(len(l1_fold2))]

# %%
l10_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_10.0/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
l10_fold0["fold"] = [0 for i in range(len(l10_fold0))]
l10_fold0["lambda"] = [10.0 for i in range(len(l10_fold0))]

# %%
l10_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_10.0/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
l10_fold1["fold"] = [1 for i in range(len(l10_fold1))]
l10_fold1["lambda"] = [10.0 for i in range(len(l10_fold1))]

# %%
l10_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_10.0/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
l10_fold2["fold"] = [2 for i in range(len(l10_fold2))]
l10_fold2["lambda"] = [10.0 for i in range(len(l10_fold2))]

# %%
l50_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_50.0/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
l50_fold0["fold"] = [0 for i in range(len(l50_fold0))]
l50_fold0["lambda"] = [50.0 for i in range(len(l50_fold0))]

# %%
l50_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_50.0/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
l50_fold1["fold"] = [1 for i in range(len(l50_fold1))]
l50_fold1["lambda"] = [50.0 for i in range(len(l50_fold1))]

# %%
l50_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_50.0/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
l50_fold2["fold"] = [2 for i in range(len(l50_fold2))]
l50_fold2["lambda"] = [50.0 for i in range(len(l50_fold2))]

# %%
l60_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_60.0/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
l60_fold0["fold"] = [0 for i in range(len(l60_fold0))]
l60_fold0["lambda"] = [60.0 for i in range(len(l60_fold0))]

# %%
l60_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_60.0/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
l60_fold1["fold"] = [1 for i in range(len(l60_fold1))]
l60_fold1["lambda"] = [60.0 for i in range(len(l60_fold1))]

# %%
l60_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_60.0/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
l60_fold2["fold"] = [2 for i in range(len(l60_fold2))]
l60_fold2["lambda"] = [60.0 for i in range(len(l60_fold2))]

# %%
l100_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_100.0/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
l100_fold0["fold"] = [0 for i in range(len(l100_fold0))]
l100_fold0["lambda"] = [100.0 for i in range(len(l100_fold0))]

# %%
l100_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_100.0/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
l100_fold1["fold"] = [1 for i in range(len(l100_fold1))]
l100_fold1["lambda"] = [100.0 for i in range(len(l100_fold1))]

# %%
l100_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_lambda/lambda_100.0/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
l100_fold2["fold"] = [2 for i in range(len(l100_fold2))]
l100_fold2["lambda"] = [100.0 for i in range(len(l100_fold2))]

# %%
df = pd.concat([l01_fold0, l01_fold1, l01_fold2,
                l1_fold0, l1_fold1, l1_fold2,
                l10_fold0, l10_fold1, l10_fold2,
                l50_fold0, l50_fold1, l50_fold2,
                l60_fold0, l60_fold1, l60_fold2,
                l100_fold0, l100_fold1, l100_fold2], ignore_index=True)

# %%
# optimizations with no edits
counts = df.groupby("lambda")["num_edits"].apply(lambda x: (x == 0).sum())
print(counts)
# Out:
# lambda
# 0.1       0
# 1.0       0
# 10.0      7
# 50.0     17
# 60.0     25
# 100.0    36
# Name: num_edits, dtype: int64

# %%
# eliminating them
df = df[df["num_edits"] > 0]

# %%
df["URQ_diff"] = df["URQ_result"] - df["URQ_init"]

# %%
# optimizations with edits but not sufficent URQ score
urq_counts = df.groupby("lambda")["URQ_diff"].apply(lambda x: (x >= 0.0).sum())
print(urq_counts)
# Out:
# lambda
# 0.1      0
# 1.0      0
# 10.0     0
# 50.0     0
# 60.0     0
# 100.0    0
# Name: URQ_diff, dtype: int64

# %%
# eliminating them
df = df[df["URQ_diff"] < 0.0]

# %%
len(df)
# Out:
# 899

# %%
# successful optimizations only, average number of edits
avg_num_edits = df.groupby("lambda")["num_edits"].mean()
print(avg_num_edits)
# Out:
# lambda
# 0.1      793.201220
# 1.0      528.579268
# 10.0     192.464968
# 50.0      66.931973
# 60.0      58.280576
# 100.0     37.976562
# Name: num_edits, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order = sorted(df["lambda"].unique())

plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="lambda", y="URQ_diff", order=order)
plt.xlabel("lambda")
plt.ylabel("URQ_diff")
plt.title("URQ_diff by lambda")
plt.tight_layout()
plt.show()

# %%
# successful optimizations only, average URQ diff
avg_urq_diff = df.groupby("lambda")["URQ_diff"].mean()
print(avg_urq_diff)
# Out:
# lambda
# 0.1     -0.344230
# 1.0     -0.337741
# 10.0    -0.307853
# 50.0    -0.243893
# 60.0    -0.238983
# 100.0   -0.214265
# Name: URQ_diff, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="lambda", y="CTCFs_num", order=order)
plt.xlabel("lambda")
plt.ylabel("CTCFs_num")
plt.title("CTCFs_num by lambda")
plt.tight_layout()
plt.show()

# %%
# successful optimizations only, average number of CTCFs
avg_ctcf_num = df.groupby("lambda")["CTCFs_num"].mean()
print(avg_ctcf_num)
# Out:
# lambda
# 0.1      7.085366
# 1.0      6.957317
# 10.0     5.038217
# 50.0     2.789116
# 60.0     2.575540
# 100.0    2.117188
# Name: CTCFs_num, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="lambda", y="FIMO_sum", order=order)
plt.xlabel("lambda")
plt.ylabel("FIMO_sum")
plt.title("FIMO_sum by lambda")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="lambda", y="FIMO_max", order=order)
plt.xlabel("lambda")
plt.ylabel("FIMO_max")
plt.title("FIMO_max by lambda")
plt.tight_layout()
plt.show()
