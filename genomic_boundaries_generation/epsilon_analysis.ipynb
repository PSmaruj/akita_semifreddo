# %%
import numpy as np
import pandas as pd

# %%
e3_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_0.001/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e3_fold0["fold"] = [0 for i in range(len(e3_fold0))]
e3_fold0["epsilon"] = [1e-3 for i in range(len(e3_fold0))]

# %%
e3_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_0.001/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e3_fold1["fold"] = [1 for i in range(len(e3_fold1))]
e3_fold1["epsilon"] = [1e-3 for i in range(len(e3_fold1))]

# %%
e3_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_0.001/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e3_fold2["fold"] = [2 for i in range(len(e3_fold2))]
e3_fold2["epsilon"] = [1e-3 for i in range(len(e3_fold2))]

# %%
e4_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_0.0001/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e4_fold0["fold"] = [0 for i in range(len(e4_fold0))]
e4_fold0["epsilon"] = [1e-4 for i in range(len(e4_fold0))]

# %%
e4_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_0.0001/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e4_fold1["fold"] = [1 for i in range(len(e4_fold1))]
e4_fold1["epsilon"] = [1e-4 for i in range(len(e4_fold1))]

# %%
e4_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_0.0001/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e4_fold2["fold"] = [2 for i in range(len(e4_fold2))]
e4_fold2["epsilon"] = [1e-4 for i in range(len(e4_fold2))]

# %%
e5_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-05/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e5_fold0["fold"] = [0 for i in range(len(e5_fold0))]
e5_fold0["epsilon"] = [1e-5 for i in range(len(e5_fold0))]

# %%
e5_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-05/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e5_fold1["fold"] = [1 for i in range(len(e5_fold1))]
e5_fold1["epsilon"] = [1e-5 for i in range(len(e5_fold1))]

# %%
e5_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-05/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e5_fold2["fold"] = [2 for i in range(len(e5_fold2))]
e5_fold2["epsilon"] = [1e-5 for i in range(len(e5_fold2))]

# %%
e6_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-06/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e6_fold0["fold"] = [0 for i in range(len(e6_fold0))]
e6_fold0["epsilon"] = [1e-6 for i in range(len(e6_fold0))]

# %%
e6_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-06/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e6_fold1["fold"] = [1 for i in range(len(e6_fold1))]
e6_fold1["epsilon"] = [1e-6 for i in range(len(e6_fold1))]

# %%
e6_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-06/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e6_fold2["fold"] = [2 for i in range(len(e6_fold2))]
e6_fold2["epsilon"] = [1e-6 for i in range(len(e6_fold2))]

# %%
e7_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-07/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e7_fold0["fold"] = [0 for i in range(len(e7_fold0))]
e7_fold0["epsilon"] = [1e-7 for i in range(len(e7_fold0))]

# %%
e7_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-07/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e7_fold1["fold"] = [1 for i in range(len(e7_fold1))]
e7_fold1["epsilon"] = [1e-7 for i in range(len(e7_fold1))]

# %%
e7_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-07/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e7_fold2["fold"] = [2 for i in range(len(e7_fold2))]
e7_fold2["epsilon"] = [1e-7 for i in range(len(e7_fold2))]

# %%
e8_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-08/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e8_fold0["fold"] = [0 for i in range(len(e8_fold0))]
e8_fold0["epsilon"] = [1e-8 for i in range(len(e8_fold0))]

# %%
e8_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-08/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e8_fold1["fold"] = [1 for i in range(len(e8_fold1))]
e8_fold1["epsilon"] = [1e-8 for i in range(len(e8_fold1))]

# %%
e8_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-08/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e8_fold2["fold"] = [2 for i in range(len(e8_fold2))]
e8_fold2["epsilon"] = [1e-8 for i in range(len(e8_fold2))]

# %%
e9_fold0 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-09/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")
e9_fold0["fold"] = [0 for i in range(len(e9_fold0))]
e9_fold0["epsilon"] = [1e-9 for i in range(len(e9_fold0))]

# %%
e9_fold1 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-09/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")
e9_fold1["fold"] = [1 for i in range(len(e9_fold1))]
e9_fold1["epsilon"] = [1e-9 for i in range(len(e9_fold1))]

# %%
e9_fold2 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/overwritten_epsilon/epsilon_1e-09/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")
e9_fold2["fold"] = [2 for i in range(len(e9_fold2))]
e9_fold2["epsilon"] = [1e-9 for i in range(len(e9_fold2))]

# %%
df = pd.concat([e3_fold0, e3_fold1, e3_fold2,
                e4_fold0, e4_fold1, e4_fold2,
                e5_fold0, e5_fold1, e5_fold2,
                e6_fold0, e6_fold1, e6_fold2,
                e7_fold0, e7_fold1, e7_fold2,
                e8_fold0, e8_fold1, e8_fold2,
                e9_fold0, e9_fold1, e9_fold2], ignore_index=True)

# %%
# optimizations with no edits
counts = df.groupby("epsilon")["num_edits"].apply(lambda x: (x == 0).sum())
print(counts)
# Out:
# epsilon
# 1.000000e-09    0
# 1.000000e-08    0
# 1.000000e-07    0
# 1.000000e-06    0
# 1.000000e-05    0
# 1.000000e-04    0
# 1.000000e-03    0
# Name: num_edits, dtype: int64

# %%
# eliminating them
df = df[df["num_edits"] > 0]

# %%
df["URQ_diff"] = df["URQ_result"] - df["URQ_init"]

# %%
# optimizations with edits but not sufficent URQ score
urq_counts = df.groupby("epsilon")["URQ_diff"].apply(lambda x: (x >= 0.0).sum())
print(urq_counts)
# Out:
# epsilon
# 1.000000e-09    0
# 1.000000e-08    0
# 1.000000e-07    0
# 1.000000e-06    0
# 1.000000e-05    0
# 1.000000e-04    0
# 1.000000e-03    0
# Name: URQ_diff, dtype: int64

# %%
# eliminating them
df = df[df["URQ_diff"] < 0.0]

# %%
len(df)
# Out:
# 1148

# %%
# successful optimizations only, average number of edits
avg_num_edits = df.groupby("epsilon")["num_edits"].mean()
print(avg_num_edits)
# Out:
# epsilon
# 1.000000e-09    419.768293
# 1.000000e-08    443.530488
# 1.000000e-07    474.109756
# 1.000000e-06    521.945122
# 1.000000e-05    628.067073
# 1.000000e-04    793.201220
# 1.000000e-03    949.030488
# Name: num_edits, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# create boxplot of num_edits grouped by epsilon
plt.figure(figsize=(8, 6))
df.boxplot(column="num_edits", by="epsilon", grid=False)

plt.title("Number of Edits by Epsilon (Successful Optimizations)")
plt.suptitle("")  # remove automatic suptitle
plt.xlabel("Epsilon")
plt.ylabel("Number of Edits")
plt.show()

# %%
order = sorted(df["epsilon"].unique())

plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="epsilon", y="URQ_diff", order=order)
plt.xlabel("epsilon")
plt.ylabel("URQ_diff")
plt.title("URQ_diff by epsilon")
plt.tight_layout()
plt.show()

# %%
# successful optimizations only, average URQ diff
avg_urq_diff = df.groupby("epsilon")["URQ_diff"].mean()
print(avg_urq_diff)
# Out:
# epsilon
# 1.000000e-09   -0.274924
# 1.000000e-08   -0.278147
# 1.000000e-07   -0.291942
# 1.000000e-06   -0.311187
# 1.000000e-05   -0.332633
# 1.000000e-04   -0.344230
# 1.000000e-03   -0.351264
# Name: URQ_diff, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="epsilon", y="CTCFs_num", order=order)
plt.xlabel("epsilon")
plt.ylabel("CTCFs_num")
plt.title("CTCFs_num by epsilon")
plt.tight_layout()
plt.show()

# %%
# successful optimizations only, average number of CTCFs
avg_ctcf_num = df.groupby("epsilon")["CTCFs_num"].mean()
print(avg_ctcf_num)
# Out:
# epsilon
# 1.000000e-09    4.548780
# 1.000000e-08    4.932927
# 1.000000e-07    5.164634
# 1.000000e-06    5.646341
# 1.000000e-05    6.609756
# 1.000000e-04    7.085366
# 1.000000e-03    7.859756
# Name: CTCFs_num, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="epsilon", y="FIMO_sum", order=order)
plt.xlabel("epsilon")
plt.ylabel("FIMO_sum")
plt.title("FIMO_sum by epsilon")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x="epsilon", y="FIMO_max", order=order)
plt.xlabel("epsilon")
plt.ylabel("FIMO_max")
plt.title("FIMO_max by epsilon")
plt.tight_layout()
plt.show()
