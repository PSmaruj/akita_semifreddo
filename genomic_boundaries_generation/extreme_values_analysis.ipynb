# %%
import numpy as np
import pandas as pd

# %%
fold0_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold0_05["fold"] = [0 for i in range(len(fold0_05))]
fold0_05["target"] = [-0.5 for i in range(len(fold0_05))]

# %%
fold1_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold1_05["fold"] = [1 for i in range(len(fold1_05))]
fold1_05["target"] = [-0.5 for i in range(len(fold1_05))]

# %%
fold2_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold2_05["fold"] = [2 for i in range(len(fold2_05))]
fold2_05["target"] = [-0.5 for i in range(len(fold2_05))]

# %%
fold3_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold3_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold3_05["fold"] = [3 for i in range(len(fold3_05))]
fold3_05["target"] = [-0.5 for i in range(len(fold3_05))]

# %%
fold4_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold4_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold4_05["fold"] = [4 for i in range(len(fold4_05))]
fold4_05["target"] = [-0.5 for i in range(len(fold4_05))]

# %%
fold5_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold5_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold5_05["fold"] = [5 for i in range(len(fold5_05))]
fold5_05["target"] = [-0.5 for i in range(len(fold5_05))]

# %%
fold6_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold6_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold6_05["fold"] = [6 for i in range(len(fold6_05))]
fold6_05["target"] = [-0.5 for i in range(len(fold6_05))]

# %%
fold7_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold7_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold7_05["fold"] = [7 for i in range(len(fold7_05))]
fold7_05["target"] = [-0.5 for i in range(len(fold7_05))]

# %%
fold0_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold0_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold0_10["fold"] = [0 for i in range(len(fold0_10))]
fold0_10["target"] = [-1.0 for i in range(len(fold0_10))]

# %%
fold1_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold1_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold1_10["fold"] = [1 for i in range(len(fold1_10))]
fold1_10["target"] = [-1.0 for i in range(len(fold1_10))]

# %%
fold2_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold2_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold2_10["fold"] = [2 for i in range(len(fold2_10))]
fold2_10["target"] = [-1.0 for i in range(len(fold2_10))]

# %%
fold3_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold3_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold3_10["fold"] = [3 for i in range(len(fold3_10))]
fold3_10["target"] = [-1.0 for i in range(len(fold3_10))]

# %%
fold4_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold4_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold4_10["fold"] = [4 for i in range(len(fold4_10))]
fold4_10["target"] = [-1.0 for i in range(len(fold4_10))]

# %%
fold5_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold5_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold5_10["fold"] = [5 for i in range(len(fold5_10))]
fold5_10["target"] = [-1.0 for i in range(len(fold5_10))]

# %%
fold6_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold6_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold6_10["fold"] = [6 for i in range(len(fold6_10))]
fold6_10["target"] = [-1.0 for i in range(len(fold6_10))]

# %%
fold7_10 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-1.0/fold7_-1.0_genomic_windows_table_results.tsv", sep="\t")

fold7_10["fold"] = [7 for i in range(len(fold7_10))]
fold7_10["target"] = [-1.0 for i in range(len(fold7_10))]

# %%
fold0_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold0_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold0_50["fold"] = [0 for i in range(len(fold0_50))]
fold0_50["target"] = [-5.0 for i in range(len(fold0_50))]

# %%
fold1_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold1_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold1_50["fold"] = [1 for i in range(len(fold1_50))]
fold1_50["target"] = [-5.0 for i in range(len(fold1_50))]

# %%
fold2_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold2_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold2_50["fold"] = [2 for i in range(len(fold2_50))]
fold2_50["target"] = [-5.0 for i in range(len(fold2_50))]

# %%
fold3_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold3_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold3_50["fold"] = [3 for i in range(len(fold3_50))]
fold3_50["target"] = [-5.0 for i in range(len(fold3_50))]

# %%
fold4_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold4_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold4_50["fold"] = [4 for i in range(len(fold4_50))]
fold4_50["target"] = [-5.0 for i in range(len(fold4_50))]

# %%
fold5_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold5_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold5_50["fold"] = [5 for i in range(len(fold5_50))]
fold5_50["target"] = [-5.0 for i in range(len(fold5_50))]

# %%
fold6_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold6_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold6_50["fold"] = [6 for i in range(len(fold6_50))]
fold6_50["target"] = [-5.0 for i in range(len(fold6_50))]

# %%
fold7_50 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-5.0/fold7_-5.0_genomic_windows_table_results.tsv", sep="\t")

fold7_50["fold"] = [7 for i in range(len(fold7_50))]
fold7_50["target"] = [-5.0 for i in range(len(fold7_50))]

# %%
df = pd.concat([fold0_05, fold1_05, fold2_05, fold3_05, fold4_05, fold5_05, fold6_05, fold7_05, 
                fold0_10, fold1_10, fold2_10, fold3_10, fold4_10, fold5_10, fold6_10, fold7_10,
                fold0_50, fold1_50, fold2_50, fold3_50, fold4_50, fold5_50, fold6_50, fold7_50], ignore_index=True)

# %%
df.columns

# %%
df["URQ_diff"] = df["URQ_result"] - df["URQ_init"]

# %%
# optimizations with no edits
counts = df.groupby("target")["num_edits"].apply(lambda x: (x == 0).sum())
print(counts)
# Out:
# target
# -5.0    78
# -1.0    75
# -0.5    54
# Name: num_edits, dtype: int64

# %%
# eliminating them
df = df[df["num_edits"] > 0]

# %%
# optimizations with edits but not sufficent URQ score
urq_counts = df.groupby("target")["URQ_diff"].apply(lambda x: (x >= 0.0).sum())
print(urq_counts)
# Out:
# target
# -5.0    0
# -1.0    0
# -0.5    0
# Name: URQ_diff, dtype: int64

# %%
# eliminating them
df = df[df["URQ_diff"] < 0.0]

# %%
# successful optimizations only, average number of edits
avg_num_edits = df.groupby("target")["num_edits"].mean()
print(avg_num_edits)
# Out:
# target
# -5.0    92.640244
# -1.0    88.404834
# -0.5    57.519886
# Name: num_edits, dtype: float64

# %%
df.columns

# %%
# successful optimizations only, average index of the last step with accepted edits
avg_last_step = df.groupby("target")["last_accepted_step"].mean()
print(avg_last_step)
# Out:
# target
# -5.0    1559.033537
# -1.0    1558.178248
# -0.5    1527.809659
# Name: last_accepted_step, dtype: float64

# %%
natural_results_path = "/scratch1/smaruj/natural_boundaries_URQmean/all_boundaries_URQ_mean.tsv"
nat_df = pd.read_csv(natural_results_path, sep="\t")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. URQ_result for all targets
plot_df = df[['URQ_result', 'target']].copy()
plot_df['value'] = plot_df['URQ_result']
plot_df['group'] = plot_df['target'].astype(str)

# 3. URQ_mean from nat_df
nat_df_box = pd.DataFrame({
    'value': nat_df['URQ_mean'],
    'group': ['natural boundaries'] * len(nat_df)
})

# 2. URQ_init for target -0.5
init_subset = df[df['target'] == -0.5]
init_df = pd.DataFrame({
    'value': init_subset['URQ_init'],
    'group': ['URQ_init'] * len(init_subset)
})

# 4. Combine in desired order: URQ_mean, URQ_init, then URQ_result
combined_df = pd.concat(
    [nat_df_box, init_df, plot_df[['value', 'group']]],
    ignore_index=True
)

# 5. Plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='group', y='value', data=combined_df)
plt.xlabel("Group")
plt.ylabel("URQ Mean")
plt.tight_layout()

# Save as SVG
plt.savefig("boundary_extreme_values.svg", format="svg")

plt.show()

# %%
# 1. CTCFs_num for all targets
plot_df = df[['CTCFs_num', 'target']].copy()
plot_df['value'] = plot_df['CTCFs_num']
plot_df['group'] = plot_df['target'].astype(str)

# 2. init_CTCFs_num for target -0.5
init_subset = df[df['target'] == -0.5]
init_df = pd.DataFrame({
    'value': init_subset['init_CTCFs_num'],
    'group': ['init_CTCFs_num'] * len(init_subset)
})

# 3. Combine
combined_df = pd.concat([init_df, plot_df[['value', 'group']]], ignore_index=True)

# 4. Plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='group', y='value', data=combined_df)
plt.xlabel("Group")
plt.ylabel("CTCFs_num")

# Save as SVG
plt.savefig("boundary_extreme_values_ctcf.svg", format="svg")

plt.tight_layout()
plt.show()

# %%
plot_df = df[['SCD', 'target']].copy()
plot_df['target'] = plot_df['target'].astype(str)

# Plot
plt.figure(figsize=(6, 5))
sns.boxplot(x='target', y='SCD', data=plot_df)
plt.xlabel("Target Category")
plt.ylabel("SCD")
plt.title("SCD by Target Category")
plt.tight_layout()
plt.show()
