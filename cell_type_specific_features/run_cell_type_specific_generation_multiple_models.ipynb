# %%
import torch

# %%
import sys
import os
sys.path.append(os.path.abspath("/home1/smaruj/pytorch_akita/"))

from akita_model.model import SeqNN

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model0 = SeqNN()
model0.load_state_dict(torch.load("/scratch1/smaruj/Akita_pytorch_models/finetuned/human_models/Krietenstein2019_H1hESC/models/Akita_v2_human_Krietenstein2019_H1hESC_model0_finetuned.pth", map_location=device))
model0.eval()
# Out:
# SeqNN(
#   (stochastic_reverse_complement): StochasticReverseComplement()
#   (stochastic_shift): StochasticShift()
#   (conv_block_1): ConvBlock(
#     (conv): Conv1d(4, 128, kernel_size=(15,), stride=(1,), padding=(7,), bias=False)
#     (batch_norm): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_tower): ConvTower(
#     (conv_tower): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ReLU()
#       (5): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): ReLU()
#       (9): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): ReLU()
#       (13): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (14): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (15): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): ReLU()
#       (17): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): ReLU()
#       (21): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (22): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (23): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): ReLU()
#       (25): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (26): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (28): ReLU()
#       (29): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (30): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (32): ReLU()
#       (33): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (34): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (35): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (36): ReLU()
#       (37): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (38): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (residual1d_block1): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block2): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block3): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block4): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block5): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block6): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(13,), dilation=(13,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block7): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(21,), dilation=(21,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block8): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(34,), dilation=(34,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block9): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(55,), dilation=(55,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block10): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(89,), dilation=(89,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block11): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(145,), dilation=(145,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (conv_reduce): ConvBlockReduce(
#     (layers): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 80, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (one_to_two): OneToTwo()
#   (conv2d_block): Conv2DBlock(
#     (block): Sequential(
#       (0): ReLU()
#       (1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (symmetrize_2d): Symmetrize2D()
#   (residual2d_block1): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block2): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(2, 2), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block3): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(4, 4), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block4): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(7, 7), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block5): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(12, 12), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block6): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(21, 21), dilation=(21, 21), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(21, 21), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (squeeze_excite): SqueezeExcite(
#     (global_pool): AdaptiveAvgPool2d(output_size=1)
#     (dense1): Linear(in_features=80, out_features=10, bias=True)
#     (dense2): Linear(in_features=10, out_features=80, bias=True)
#     (norm): BatchNorm1d(80, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#   )
#   (cropping_2d): Cropping2D()
#   (upper_tri): UpperTri()
#   (final): Final(
#     (dense): Linear(in_features=80, out_features=1, bias=True)
#   )
# )

# %%
model1 = SeqNN()
model1.load_state_dict(torch.load("/scratch1/smaruj/Akita_pytorch_models/finetuned/human_models/Krietenstein2019_H1hESC/models/Akita_v2_human_Krietenstein2019_H1hESC_model1_finetuned.pth", map_location=device))
model1.eval()
# Out:
# SeqNN(
#   (stochastic_reverse_complement): StochasticReverseComplement()
#   (stochastic_shift): StochasticShift()
#   (conv_block_1): ConvBlock(
#     (conv): Conv1d(4, 128, kernel_size=(15,), stride=(1,), padding=(7,), bias=False)
#     (batch_norm): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_tower): ConvTower(
#     (conv_tower): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ReLU()
#       (5): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): ReLU()
#       (9): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): ReLU()
#       (13): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (14): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (15): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): ReLU()
#       (17): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): ReLU()
#       (21): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (22): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (23): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): ReLU()
#       (25): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (26): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (28): ReLU()
#       (29): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (30): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (32): ReLU()
#       (33): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (34): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (35): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (36): ReLU()
#       (37): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (38): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (residual1d_block1): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block2): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block3): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block4): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block5): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block6): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(13,), dilation=(13,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block7): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(21,), dilation=(21,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block8): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(34,), dilation=(34,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block9): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(55,), dilation=(55,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block10): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(89,), dilation=(89,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block11): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(145,), dilation=(145,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (conv_reduce): ConvBlockReduce(
#     (layers): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 80, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (one_to_two): OneToTwo()
#   (conv2d_block): Conv2DBlock(
#     (block): Sequential(
#       (0): ReLU()
#       (1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (symmetrize_2d): Symmetrize2D()
#   (residual2d_block1): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block2): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(2, 2), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block3): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(4, 4), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block4): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(7, 7), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block5): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(12, 12), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block6): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(21, 21), dilation=(21, 21), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(21, 21), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (squeeze_excite): SqueezeExcite(
#     (global_pool): AdaptiveAvgPool2d(output_size=1)
#     (dense1): Linear(in_features=80, out_features=10, bias=True)
#     (dense2): Linear(in_features=10, out_features=80, bias=True)
#     (norm): BatchNorm1d(80, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#   )
#   (cropping_2d): Cropping2D()
#   (upper_tri): UpperTri()
#   (final): Final(
#     (dense): Linear(in_features=80, out_features=1, bias=True)
#   )
# )

# %%
model4 = SeqNN()
model4.load_state_dict(torch.load("/scratch1/smaruj/Akita_pytorch_models/finetuned/human_models/Krietenstein2019_HFF/models/Akita_v2_human_Krietenstein2019_HFF_model0_finetuned.pth", map_location=device))
model4.eval()
# Out:
# SeqNN(
#   (stochastic_reverse_complement): StochasticReverseComplement()
#   (stochastic_shift): StochasticShift()
#   (conv_block_1): ConvBlock(
#     (conv): Conv1d(4, 128, kernel_size=(15,), stride=(1,), padding=(7,), bias=False)
#     (batch_norm): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_tower): ConvTower(
#     (conv_tower): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ReLU()
#       (5): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): ReLU()
#       (9): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): ReLU()
#       (13): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (14): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (15): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): ReLU()
#       (17): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): ReLU()
#       (21): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (22): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (23): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): ReLU()
#       (25): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (26): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (28): ReLU()
#       (29): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (30): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (32): ReLU()
#       (33): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (34): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (35): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (36): ReLU()
#       (37): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (38): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (residual1d_block1): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block2): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block3): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block4): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block5): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block6): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(13,), dilation=(13,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block7): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(21,), dilation=(21,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block8): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(34,), dilation=(34,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block9): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(55,), dilation=(55,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block10): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(89,), dilation=(89,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block11): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(145,), dilation=(145,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (conv_reduce): ConvBlockReduce(
#     (layers): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 80, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (one_to_two): OneToTwo()
#   (conv2d_block): Conv2DBlock(
#     (block): Sequential(
#       (0): ReLU()
#       (1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (symmetrize_2d): Symmetrize2D()
#   (residual2d_block1): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block2): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(2, 2), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block3): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(4, 4), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block4): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(7, 7), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block5): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(12, 12), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block6): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(21, 21), dilation=(21, 21), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(21, 21), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (squeeze_excite): SqueezeExcite(
#     (global_pool): AdaptiveAvgPool2d(output_size=1)
#     (dense1): Linear(in_features=80, out_features=10, bias=True)
#     (dense2): Linear(in_features=10, out_features=80, bias=True)
#     (norm): BatchNorm1d(80, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#   )
#   (cropping_2d): Cropping2D()
#   (upper_tri): UpperTri()
#   (final): Final(
#     (dense): Linear(in_features=80, out_features=1, bias=True)
#   )
# )

# %%
model5 = SeqNN()
model5.load_state_dict(torch.load("/scratch1/smaruj/Akita_pytorch_models/finetuned/human_models/Krietenstein2019_HFF/models/Akita_v2_human_Krietenstein2019_HFF_model1_finetuned.pth", map_location=device))
model5.eval()
# Out:
# SeqNN(
#   (stochastic_reverse_complement): StochasticReverseComplement()
#   (stochastic_shift): StochasticShift()
#   (conv_block_1): ConvBlock(
#     (conv): Conv1d(4, 128, kernel_size=(15,), stride=(1,), padding=(7,), bias=False)
#     (batch_norm): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (pool): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_tower): ConvTower(
#     (conv_tower): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): ReLU()
#       (5): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (8): ReLU()
#       (9): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (10): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (12): ReLU()
#       (13): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (14): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (15): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): ReLU()
#       (17): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (18): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (19): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (20): ReLU()
#       (21): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (22): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (23): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (24): ReLU()
#       (25): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (26): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (27): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (28): ReLU()
#       (29): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (30): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (31): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (32): ReLU()
#       (33): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (34): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (35): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (36): ReLU()
#       (37): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (38): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (39): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (residual1d_block1): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(1,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block2): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,), dilation=(2,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block3): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(3,), dilation=(3,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block4): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(5,), dilation=(5,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block5): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(8,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block6): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(13,), dilation=(13,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block7): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(21,), dilation=(21,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block8): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(34,), dilation=(34,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block9): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(55,), dilation=(55,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block10): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(89,), dilation=(89,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (residual1d_block11): ResidualDilatedBlock1D(
#     (relu1): ReLU()
#     (conv1): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(145,), dilation=(145,), bias=False)
#     (norm1): BatchNorm1d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (conv2): Conv1d(64, 128, kernel_size=(1,), stride=(1,), bias=False)
#     (norm2): BatchNorm1d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (conv_reduce): ConvBlockReduce(
#     (layers): Sequential(
#       (0): ReLU()
#       (1): Conv1d(128, 80, kernel_size=(5,), stride=(1,), padding=(2,), bias=False)
#       (2): BatchNorm1d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#     )
#   )
#   (one_to_two): OneToTwo()
#   (conv2d_block): Conv2DBlock(
#     (block): Sequential(
#       (0): ReLU()
#       (1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (symmetrize_2d): Symmetrize2D()
#   (residual2d_block1): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block2): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(2, 2), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block3): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(4, 4), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block4): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(7, 7), dilation=(7, 7), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(7, 7), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block5): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(12, 12), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (residual2d_block6): DilatedResidualBlock2D(
#     (relu): ReLU()
#     (conv1): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=(21, 21), dilation=(21, 21), bias=False)
#     (norm1): BatchNorm2d(40, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(40, 80, kernel_size=(1, 1), stride=(1, 1), dilation=(21, 21), bias=False)
#     (norm2): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (symmetrize): Symmetrize2D()
#   )
#   (squeeze_excite): SqueezeExcite(
#     (global_pool): AdaptiveAvgPool2d(output_size=1)
#     (dense1): Linear(in_features=80, out_features=10, bias=True)
#     (dense2): Linear(in_features=10, out_features=80, bias=True)
#     (norm): BatchNorm1d(80, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#   )
#   (cropping_2d): Cropping2D()
#   (upper_tri): UpperTri()
#   (final): Final(
#     (dense): Linear(in_features=80, out_features=1, bias=True)
#   )
# )

# %%
import pandas as pd

# %%
FOLD = 0

# %%
df = pd.read_csv(f"/scratch1/smaruj/generate_cell_type_specific_features/fold0_HUMAN_selected_genomic_windows_centered.tsv", sep="\t")

# %%
# df

# %%
fountain_mask_path = "/scratch1/smaruj/generate_cell_type_specific_features/boundary_indices.pt"

# %%
import sys
sys.path.insert(0, "/home1/smaruj/ledidi/ledidi")
from ledidi_multiple_models_sum_mod import Ledidi
# from ledidi_multiple_models_sum_efficient import Ledidi

# %%
bin_size = 2048
cropping_applied = 64
padding_bins = 2
padding = padding_bins * bin_size

# 256 +- 25 (50 bins in the center)
slice_0_bins = [i for i in range(231, 281)]
slice_0_start = (min(slice_0_bins) + cropping_applied - padding_bins) * bin_size
slice_0_end = (max(slice_0_bins) + 1 + cropping_applied + padding_bins) * bin_size

# %%
models = [model0, model1, model4, model5]

# %%
for row in df[1:2].itertuples(index=False):
    chrom, pred_start, pred_end = row.chrom, row.centered_start, row.centered_end
    
    print(f"Fountain generation for genome location: {chrom}:{pred_start}-{pred_end}")
    
    X = torch.load(f"/scratch1/smaruj/generate_cell_type_specific_features/ohe_X_HUMAN/fold{FOLD}/{chrom}_{pred_start}_{pred_end}_X.pt", weights_only=True, map_location=device)

    target_m0 = torch.load(f"/scratch1/smaruj/generate_cell_type_specific_features/target_H1hESC_strong_boundary/model0/{chrom}_{pred_start}_{pred_end}_target.pt", weights_only=True, map_location=device)
    target_m1 = torch.load(f"/scratch1/smaruj/generate_cell_type_specific_features/target_H1hESC_strong_boundary/model1/{chrom}_{pred_start}_{pred_end}_target.pt", weights_only=True, map_location=device)
    target_m2 = torch.load(f"/scratch1/smaruj/generate_cell_type_specific_features/target_HFF_weak_boundary/model0/{chrom}_{pred_start}_{pred_end}_target.pt", weights_only=True, map_location=device)
    target_m3 = torch.load(f"/scratch1/smaruj/generate_cell_type_specific_features/target_HFF_weak_boundary/model1/{chrom}_{pred_start}_{pred_end}_target.pt", weights_only=True, map_location=device)
    
    target = [target_m0, target_m1, target_m2, target_m3]
    
    tower_output_path_list = [f"/scratch1/smaruj/generate_cell_type_specific_features/tower_output_H1hESC/model0/{chrom}_{pred_start}_{pred_end}_tower_out.pt",
                              f"/scratch1/smaruj/generate_cell_type_specific_features/tower_output_H1hESC/model1/{chrom}_{pred_start}_{pred_end}_tower_out.pt",
                              f"/scratch1/smaruj/generate_cell_type_specific_features/tower_output_HFF/model0/{chrom}_{pred_start}_{pred_end}_tower_out.pt",
                              f"/scratch1/smaruj/generate_cell_type_specific_features/tower_output_HFF/model1/{chrom}_{pred_start}_{pred_end}_tower_out.pt"]
    
    wrapper = Ledidi(models, 
                 input_loss=torch.nn.L1Loss(reduction='sum'), 
                 output_loss=torch.nn.L1Loss(reduction='sum'),
                 batch_size=1,
                 max_iter=2000,
                 early_stopping_iter=2000,
                 return_history=False,
                 verbose=True,
                 bin_size=2048,
                 input_mask_slices_0=[i for i in range(231, 281)],
                 cropping_applied=64,
                 output_mask_path=fountain_mask_path,
                 use_semifreddo=True,
                 semifreddo_temp_output_path_list=tower_output_path_list,
                 punish_ctcf=False,
                 ctcf_meme_path=None
                 ).cuda()
    
    slice_0_torch = X[:, :, slice_0_start:slice_0_end]
    
    x_bar_slice_0, last_update, _, _, _ = wrapper.fit_transform(X=slice_0_torch, y_bar_list=target)
    
    # torch.save(x_bar_slice_0[:,:,padding:-padding], f"/scratch1/smaruj/genomic_insertion_loci/results/{chrom}_{pred_start}_{pred_end}_slice.pt")
# Out:
# Fountain generation for genome location: chr1:29237248-30547968
# Model 0 in train mode: False
# Model 1 in train mode: False
# Model 2 in train mode: False
# Model 3 in train mode: False
# Gradients enabled for weights - slice 0: True
# Weights shape - slice 0: torch.Size([1, 4, 102400])
# /home1/smaruj/miniconda3/envs/pytorch_hic/lib/python3.10/site-packages/torch/nn/modules/conv.py:306: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv1d(input, weight, bias, self.stride,
# Local loss applied.
# iter=I	input_loss=0.0	output_loss=8.577e+04	total_loss=8.577e+04	time=0.0
# iter=100	input_loss=1.126e+04	output_loss=4.062e+04	total_loss=4.174e+04	time=29.86
# iter=200	input_loss=1.318e+04	output_loss=3.712e+04	total_loss=3.844e+04	time=29.54
# iter=300	input_loss=1.518e+04	output_loss=3.642e+04	total_loss=3.794e+04	time=29.56
# iter=400	input_loss=1.629e+04	output_loss=3.638e+04	total_loss=3.801e+04	time=29.56
# iter=500	input_loss=1.777e+04	output_loss=3.609e+04	total_loss=3.787e+04	time=29.56
# iter=600	input_loss=1.874e+04	output_loss=3.569e+04	total_loss=3.756e+04	time=29.56
# iter=700	input_loss=1.944e+04	output_loss=3.575e+04	total_loss=3.769e+04	time=29.54
# iter=800	input_loss=2.026e+04	output_loss=3.554e+04	total_loss=3.756e+04	time=29.54
# iter=900	input_loss=2.024e+04	output_loss=3.489e+04	total_loss=3.691e+04	time=29.56
# iter=1000	input_loss=2.061e+04	output_loss=3.497e+04	total_loss=3.703e+04	time=29.56
# iter=1100	input_loss=2.071e+04	output_loss=3.546e+04	total_loss=3.753e+04	time=29.56
# iter=1200	input_loss=2.125e+04	output_loss=3.486e+04	total_loss=3.698e+04	time=29.55
# iter=1300	input_loss=2.138e+04	output_loss=3.499e+04	total_loss=3.713e+04	time=29.55
# iter=1400	input_loss=2.158e+04	output_loss=3.467e+04	total_loss=3.683e+04	time=29.6
# iter=1500	input_loss=2.136e+04	output_loss=3.47e+04	total_loss=3.684e+04	time=29.55
# iter=1600	input_loss=2.188e+04	output_loss=3.468e+04	total_loss=3.686e+04	time=29.55
# iter=1700	input_loss=2.131e+04	output_loss=3.476e+04	total_loss=3.689e+04	time=29.55
# iter=1800	input_loss=2.163e+04	output_loss=3.477e+04	total_loss=3.693e+04	time=29.55
# iter=1900	input_loss=2.148e+04	output_loss=3.541e+04	total_loss=3.756e+04	time=29.56
# iter=2000	input_loss=2.198e+04	output_loss=3.479e+04	total_loss=3.699e+04	time=29.55
# iter=F	input_loss=2.131e+04	output_loss=3.451e+04	total_loss=3.664e+04	time=591.4
# Last iteration with update:  1440

# %%
x_bar_slice_0

# %%
slice = [i for i in range(231, 281)]
cropping = 64
bin_size = 2048

edit_start = (min(slice) + cropping) * bin_size
edit_end = (max(slice) + 1 + cropping) * bin_size

# %%
edit_start, edit_end

# %%
edit_end - edit_start

# %%
2 * 2048

# %%
x_bar_slice_0[:, :, 4096:-4096].shape

# %%
chr11:65677312-66988032

# %%
X = torch.load(f"/scratch1/smaruj/generate_genomic_boundary/ohe_X/fold0/chr11_65677312_66988032_X.pt", weights_only=True, map_location=device)

# %%
with torch.no_grad():
    og_pred_model0 = model0(X)

# %%
X_new = X.clone()

# %%
X_new[:, :, edit_start:edit_end] = x_bar_slice_0[:, :, 4096:-4096]

# %%
X_new

# %%
with torch.no_grad():
    pred_model0 = model0(X_new)
    pred_model1 = model1(X_new)
    pred_model2 = model2(X_new)
    pred_model3 = model3(X_new)
    pred_model4 = model4(X_new)
    pred_model5 = model5(X_new)
    pred_model6 = model6(X_new)
    pred_model7 = model7(X_new)

# %%
# Helper function to set diagonal elements to a specific value
def set_diag(matrix, value, k):
    # Explicitly set the diagonal to 'value' (in this case, np.nan) for each k
    rows, cols = matrix.shape
    for i in range(rows):
        if 0 <= i + k < cols:
            matrix[i, i + k] = value

def from_upper_triu(vector_repr, matrix_len, num_diags):
    # Ensure vector_repr is a NumPy array (if it's a PyTorch tensor, convert it)
    if isinstance(vector_repr, torch.Tensor):
        vector_repr = vector_repr.detach().flatten().cpu().numpy()  # Flatten and convert to NumPy array

    # Initialize a zero matrix of shape (matrix_len, matrix_len)
    z = np.zeros((matrix_len, matrix_len))

    # Get the indices for the upper triangular matrix
    triu_tup = np.triu_indices(matrix_len, num_diags)

    # Assign the values from the vector_repr to the upper triangular part of the matrix
    z[triu_tup] = vector_repr

    # Set the diagonals specified by num_diags to np.nan
    for i in range(-num_diags + 1, num_diags):
        set_diag(z, np.nan, i)

    # Ensure the matrix is symmetric
    return z + z.T

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(og_pred_model0, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model0, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model1, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model2, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model3, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model4, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model5, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model6, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
plt.figure(figsize=(8, 8))
matrix = from_upper_triu(pred_model7, matrix_len=512, num_diags=2)
plt.matshow(matrix.astype(np.float16), cmap='RdBu_r', vmin=-0.6, vmax=0.6)
# plt.colorbar()
# plt.savefig("fountain_difference.svg", format='svg')
plt.show()

# %%
# Convert to NumPy
X_new_np = X_new.detach().cpu().numpy()  # ensures it's on CPU and detached from graph

# Save to .npy file
np.save("/scratch1/smaruj/generate_genomic_fountain/test_X_new.npy", X_new_np)
