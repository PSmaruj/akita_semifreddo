# %%
from alphagenome import colab_utils
from alphagenome.data import gene_annotation, genome, track_data, transcript
from alphagenome.models import dna_client
from alphagenome.visualization import plot_components
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
api_key = "AIzaSyBh9ICxEr8WOH63OELhl13TtqI1xvNo6LY"

# %%
# default alphagenome model
dna_model = dna_client.create(api_key)

# %%
dna_model.output_metadata().concatenate()
# Out:
#                    name strand Assay title ontology_curie  \
# 0   CL:0000084 ATAC-seq      .    ATAC-seq     CL:0000084
# 1   CL:0000100 ATAC-seq      .    ATAC-seq     CL:0000100
# 2   CL:0000236 ATAC-seq      .    ATAC-seq     CL:0000236
# 3   CL:0000623 ATAC-seq      .    ATAC-seq     CL:0000623
# 4   CL:0000624 ATAC-seq      .    ATAC-seq     CL:0000624
# ..                  ...    ...         ...            ...
# 7           ENCSR182QNJ      -     PRO-cap    EFO:0001099
# 8           ENCSR740IPL      -     PRO-cap    EFO:0002067
# 9           ENCSR797DEF      -     PRO-cap    EFO:0002819
# 10          ENCSR801ECP      -     PRO-cap     CL:0002618
# 11          ENCSR860TYZ      -     PRO-cap    EFO:0001200
#
#                         biosample_name                 biosample_type  \
# 0                               T-cell                   primary_cell
# 1                         motor neuron  in_vitro_differentiated_cells
# 2                               B cell                   primary_cell
# 3                  natural killer cell                   primary_cell
# 4      CD4-positive, alpha-beta T cell                   primary_cell
# ..                                 ...                            ...
# 7                               Caco-2                      cell_line
# 8                                 K562                      cell_line
# 9                                Calu3                      cell_line
# 10  endothelial cell of umbilical vein                   primary_cell
# 11                             MCF 10A                      cell_line
#
#    biosample_life_stage data_source endedness genetically_modified  \
# 0                 adult      encode    paired                False
# 1                 adult      encode    paired                False
# 2                 adult      encode    paired                False
# 3                 adult      encode    paired                False
# 4                 adult      encode    paired                False
# ..                  ...         ...       ...                  ...
# 7                   NaN      encode       NaN                False
# 8                   NaN      encode       NaN                False
# 9                   NaN      encode       NaN                False
# 10                  NaN      encode       NaN                False
# 11                  NaN      encode       NaN                False
#
#     nonzero_mean        output_type gtex_tissue histone_mark  \
# 0       0.739741    OutputType.ATAC         NaN          NaN
# 1       0.273136    OutputType.ATAC         NaN          NaN
# 2       4.700081    OutputType.ATAC         NaN          NaN
# 3       0.938715    OutputType.ATAC         NaN          NaN
# 4       4.365206    OutputType.ATAC         NaN          NaN
# ..           ...                ...         ...          ...
# 7      14.002803  OutputType.PROCAP         NaN          NaN
# 8      15.765458  OutputType.PROCAP         NaN          NaN
# 9      12.281321  OutputType.PROCAP         NaN          NaN
# 10     13.973692  OutputType.PROCAP         NaN          NaN
# 11      8.229502  OutputType.PROCAP         NaN          NaN
#
#    transcription_factor
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
#
# [5563 rows x 15 columns]

# %%
# Load metadata objects for mouse (mm10)
output_metadata = dna_model.output_metadata(
    organism=dna_client.Organism.HOMO_SAPIENS
).concatenate()

# %%
output_metadata
# Out:
#                    name strand Assay title ontology_curie  \
# 0   CL:0000084 ATAC-seq      .    ATAC-seq     CL:0000084
# 1   CL:0000100 ATAC-seq      .    ATAC-seq     CL:0000100
# 2   CL:0000236 ATAC-seq      .    ATAC-seq     CL:0000236
# 3   CL:0000623 ATAC-seq      .    ATAC-seq     CL:0000623
# 4   CL:0000624 ATAC-seq      .    ATAC-seq     CL:0000624
# ..                  ...    ...         ...            ...
# 7           ENCSR182QNJ      -     PRO-cap    EFO:0001099
# 8           ENCSR740IPL      -     PRO-cap    EFO:0002067
# 9           ENCSR797DEF      -     PRO-cap    EFO:0002819
# 10          ENCSR801ECP      -     PRO-cap     CL:0002618
# 11          ENCSR860TYZ      -     PRO-cap    EFO:0001200
#
#                         biosample_name                 biosample_type  \
# 0                               T-cell                   primary_cell
# 1                         motor neuron  in_vitro_differentiated_cells
# 2                               B cell                   primary_cell
# 3                  natural killer cell                   primary_cell
# 4      CD4-positive, alpha-beta T cell                   primary_cell
# ..                                 ...                            ...
# 7                               Caco-2                      cell_line
# 8                                 K562                      cell_line
# 9                                Calu3                      cell_line
# 10  endothelial cell of umbilical vein                   primary_cell
# 11                             MCF 10A                      cell_line
#
#    biosample_life_stage data_source endedness genetically_modified  \
# 0                 adult      encode    paired                False
# 1                 adult      encode    paired                False
# 2                 adult      encode    paired                False
# 3                 adult      encode    paired                False
# 4                 adult      encode    paired                False
# ..                  ...         ...       ...                  ...
# 7                   NaN      encode       NaN                False
# 8                   NaN      encode       NaN                False
# 9                   NaN      encode       NaN                False
# 10                  NaN      encode       NaN                False
# 11                  NaN      encode       NaN                False
#
#     nonzero_mean        output_type gtex_tissue histone_mark  \
# 0       0.739741    OutputType.ATAC         NaN          NaN
# 1       0.273136    OutputType.ATAC         NaN          NaN
# 2       4.700081    OutputType.ATAC         NaN          NaN
# 3       0.938715    OutputType.ATAC         NaN          NaN
# 4       4.365206    OutputType.ATAC         NaN          NaN
# ..           ...                ...         ...          ...
# 7      14.002803  OutputType.PROCAP         NaN          NaN
# 8      15.765458  OutputType.PROCAP         NaN          NaN
# 9      12.281321  OutputType.PROCAP         NaN          NaN
# 10     13.973692  OutputType.PROCAP         NaN          NaN
# 11      8.229502  OutputType.PROCAP         NaN          NaN
#
#    transcription_factor
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
#
# [5563 rows x 15 columns]

# %%
output_metadata["Assay title"].unique()
# Out:
# array(['ATAC-seq', 'LQhCAGE', 'hCAGE', 'DNase-seq', 'polyA plus RNA-seq',
#        'total RNA-seq', 'Histone ChIP-seq', 'TF ChIP-seq', nan, 'Micro-C',
#        'in situ Hi-C', 'Dilution Hi-C', 'PRO-cap'], dtype=object)

# %%
output_metadata[output_metadata["Assay title"] == "Micro-C"]
# Out:
#                 name strand Assay title ontology_curie biosample_name  \
# 0   4dn:4DNFI9GMP2J8      .     Micro-C    EFO:0003042        H1-hESC
# 1   4dn:4DNFI9FVHJZQ      .     Micro-C    EFO:0009318          HFFc6
# 18  4dn:4DNFINQYW56E      .     Micro-C    EFO:0003042        H1-hESC
#
#    biosample_type biosample_life_stage data_source endedness  \
# 0       cell_line                  NaN  4dnucleome       NaN
# 1       cell_line                  NaN  4dnucleome       NaN
# 18      cell_line                  NaN  4dnucleome       NaN
#
#    genetically_modified  nonzero_mean              output_type gtex_tissue  \
# 0                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 1                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 18                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
#
#    histone_mark transcription_factor
# 0           NaN                  NaN
# 1           NaN                  NaN
# 18          NaN                  NaN

# %%
output_metadata[output_metadata["Assay title"] == "in situ Hi-C"]
# Out:
#                 name strand   Assay title ontology_curie biosample_name  \
# 2   4dn:4DNFIFLDVASC      .  in situ Hi-C    EFO:0002824         HCT116
# 3   4dn:4DNFIJTOIGOI      .  in situ Hi-C    EFO:0001196         IMR-90
# 4   4dn:4DNFIXP4QG5B      .  in situ Hi-C    EFO:0002784        GM12878
# 5   4dn:4DNFI2VYSX9M      .  in situ Hi-C    EFO:0007073          CyT49
# 6   4dn:4DNFI4DCV74I      .  in situ Hi-C    EFO:0003045             H9
# 7   4dn:4DNFI5IHU27G      .  in situ Hi-C    EFO:0005903          KBM-7
# 8   4dn:4DNFI6HDY7WZ      .  in situ Hi-C    EFO:0003042        H1-hESC
# 9   4dn:4DNFI82R42AD      .  in situ Hi-C    EFO:0003042        H1-hESC
# 10  4dn:4DNFI8RH55DO      .  in situ Hi-C    EFO:0003045             H9
# 11  4dn:4DNFIB59T7NN      .  in situ Hi-C    EFO:0009318          HFFc6
# 12  4dn:4DNFIBM9QCFG      .  in situ Hi-C    EFO:0002791        HeLa-S3
# 13  4dn:4DNFIIOUG5RF      .  in situ Hi-C    EFO:0003045             H9
# 14  4dn:4DNFIK3NF6R2      .  in situ Hi-C    EFO:0007073          CyT49
# 15  4dn:4DNFILP99QJS      .  in situ Hi-C    EFO:0002824         HCT116
# 17  4dn:4DNFINFQV712      .  in situ Hi-C    EFO:0003042        H1-hESC
# 19  4dn:4DNFINXSKZ4F      .  in situ Hi-C    EFO:0007073          CyT49
# 20  4dn:4DNFIPO1DGLH      .  in situ Hi-C    EFO:0003045             H9
# 21  4dn:4DNFIRO3DQCO      .  in situ Hi-C    EFO:0003045             H9
# 22  4dn:4DNFIS6HAUPP      .  in situ Hi-C    EFO:0001187          HepG2
# 23  4dn:4DNFIT5YVTLO      .  in situ Hi-C    EFO:0003045             H9
# 24  4dn:4DNFIVKQADWM      .  in situ Hi-C    EFO:0009747        GM25256
# 25  4dn:4DNFIW8IXCX1      .  in situ Hi-C    EFO:0003042        H1-hESC
# 26  4dn:4DNFIXOWKAM6      .  in situ Hi-C    EFO:0007073          CyT49
# 27  4dn:4DNFIYGPDLKF      .  in situ Hi-C    EFO:0009747        GM25256
#
#                    biosample_type biosample_life_stage data_source endedness  \
# 2                       cell_line                  NaN  4dnucleome       NaN
# 3                       cell_line                  NaN  4dnucleome       NaN
# 4                       cell_line                  NaN  4dnucleome       NaN
# 5                       cell_line                  NaN  4dnucleome       NaN
# 6                       cell_line                  NaN  4dnucleome       NaN
# 7                       cell_line                  NaN  4dnucleome       NaN
# 8                       cell_line                  NaN  4dnucleome       NaN
# 9                       cell_line                  NaN  4dnucleome       NaN
# 10                      cell_line                  NaN  4dnucleome       NaN
# 11                      cell_line                  NaN  4dnucleome       NaN
# 12                      cell_line                  NaN  4dnucleome       NaN
# 13                      cell_line                  NaN  4dnucleome       NaN
# 14                      cell_line                  NaN  4dnucleome       NaN
# 15                      cell_line                  NaN  4dnucleome       NaN
# 17                      cell_line                  NaN  4dnucleome       NaN
# 19                      cell_line                  NaN  4dnucleome       NaN
# 20                      cell_line                  NaN  4dnucleome       NaN
# 21                      cell_line                  NaN  4dnucleome       NaN
# 22                      cell_line                  NaN  4dnucleome       NaN
# 23                      cell_line                  NaN  4dnucleome       NaN
# 24  in_vitro_differentiated_cells                  NaN  4dnucleome       NaN
# 25                      cell_line                  NaN  4dnucleome       NaN
# 26                      cell_line                  NaN  4dnucleome       NaN
# 27  in_vitro_differentiated_cells                  NaN  4dnucleome       NaN
#
#    genetically_modified  nonzero_mean              output_type gtex_tissue  \
# 2                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 3                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 4                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 5                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 6                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 7                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 8                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 9                   NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 10                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 11                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 12                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 13                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 14                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 15                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 17                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 19                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 20                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 21                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 22                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 23                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 24                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 25                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 26                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
# 27                  NaN           NaN  OutputType.CONTACT_MAPS         NaN
#
#    histone_mark transcription_factor
# 2           NaN                  NaN
# 3           NaN                  NaN
# 4           NaN                  NaN
# 5           NaN                  NaN
# 6           NaN                  NaN
# 7           NaN                  NaN
# 8           NaN                  NaN
# 9           NaN                  NaN
# 10          NaN                  NaN
# 11          NaN                  NaN
# 12          NaN                  NaN
# 13          NaN                  NaN
# 14          NaN                  NaN
# 15          NaN                  NaN
# 17          NaN                  NaN
# 19          NaN                  NaN
# 20          NaN                  NaN
# 21          NaN                  NaN
# 22          NaN                  NaN
# 23          NaN                  NaN
# 24          NaN                  NaN
# 25          NaN                  NaN
# 26          NaN                  NaN
# 27          NaN                  NaN

# %%
BED_FILE = "/project/fudenber_735/tensorflow_models/akita/v2/data/mm10/sequences.bed"

# %%
df = pd.read_csv(BED_FILE, sep="\t", header=None, names=["chrom", "start", "end", "fold"])

# %%
FOLD = 0

# %%
df = df[df["fold"] == f"fold{FOLD}"].reset_index(drop=True)

# %%
# removing cropping
df["ag_start"] = df["start"] + 64*2048
df["ag_end"] = df["end"] - 64*2048

# %%
import random
from pyfaidx import Fasta

# %%
def one_hot_encode_sequence(sequence_obj):
    # Convert pyfaidx.Sequence object to string
    sequence = str(sequence_obj).upper()
    
    # Define the mapping from bases to integers
    base_to_int = {'A': 0, 'C': 1, 'G': 2, 'T': 3}
    valid_bases = list(base_to_int.keys())

    # Step 1: Convert sequence to integer encoding with random base for 'N'
    encoded_indices = []
    for base in sequence:
        if base in base_to_int:
            encoded_indices.append(base_to_int[base])
        else:
            random_base = random.choice(valid_bases)
            encoded_indices.append(base_to_int[random_base])

    # Step 2: One-hot encode the sequence
    encoded_sequence = np.array(encoded_indices)
    one_hot_encoded = np.zeros((4, len(encoded_sequence)), dtype=np.float32)
    one_hot_encoded[encoded_sequence, np.arange(len(encoded_sequence))] = 1

    input_sequence = np.expand_dims(one_hot_encoded, axis=0)

    return input_sequence

# %%
df = df[df["fold"] == f"fold{FOLD}"].reset_index(drop=True)

# %%
fasta_file = "/project/fudenber_735/genomes/mm10/mm10.fa"
genome = Fasta(fasta_file)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_map(matrix, vmin=-0.6, vmax=0.6, palette="RdBu_r", width=5, height=5):
    fig, axes = plt.subplots(1, 1, figsize=(width, height))

    sns.heatmap(
        matrix,
        vmin=vmin,
        vmax=vmax,
        cbar=False,
        cmap=palette,
        square=True,
        xticklabels=False,
        yticklabels=False,
        ax=axes
    )

    plt.tight_layout()
    plt.show()

# %%
out_dir = "/scratch1/smaruj/alpha_genome_validation/fold0"

# %%
import os

# %%
for i, row in enumerate(df.itertuples(index=False)):
    chrom, start, end = row.chrom, row.ag_start, row.ag_end
    seq = genome[chrom][start:end].seq.upper()
    
    print(i, chrom, start, end)
    
    # print(seq[:10])
    
    output = dna_model.predict_sequence(
        organism=dna_client.Organism.MUS_MUSCULUS,
        sequence=seq,  # Pad to valid sequence length.
        requested_outputs=[dna_client.OutputType.CONTACT_MAPS],
        # ontology_terms=['EFO:0003042'], #H1-hESC
        ontology_terms=['EFO:0004038'] # mouse ontology
    )
    
    # print(output.contact_maps.values.shape)
    
    matrix = output.contact_maps.values[:,:,0]
    
    # plot_map(matrix)
    
    # Construct filename
    filename = f"{chrom}_{start}_{end}.npy"
    filepath = os.path.join(out_dir, filename)

    # Save the map
    np.save(filepath, matrix)
    print(f"Saved: {filepath}")
