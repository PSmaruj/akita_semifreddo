# %%
import numpy as np
import pandas as pd

# %%
fold0_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold0_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold0_05["fold"] = [0 for i in range(len(fold0_05))]
fold0_05["target"] = [-0.5 for i in range(len(fold0_05))]

# %%
fold1_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold1_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold1_05["fold"] = [1 for i in range(len(fold1_05))]
fold1_05["target"] = [-0.5 for i in range(len(fold1_05))]

# %%
fold2_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold2_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold2_05["fold"] = [2 for i in range(len(fold2_05))]
fold2_05["target"] = [-0.5 for i in range(len(fold2_05))]

# %%
fold3_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold3_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold3_05["fold"] = [3 for i in range(len(fold3_05))]
fold3_05["target"] = [-0.5 for i in range(len(fold3_05))]

# %%
fold4_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold4_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold4_05["fold"] = [4 for i in range(len(fold4_05))]
fold4_05["target"] = [-0.5 for i in range(len(fold4_05))]

# %%
fold5_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold5_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold5_05["fold"] = [5 for i in range(len(fold5_05))]
fold5_05["target"] = [-0.5 for i in range(len(fold5_05))]

# %%
fold6_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold6_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold6_05["fold"] = [6 for i in range(len(fold6_05))]
fold6_05["target"] = [-0.5 for i in range(len(fold6_05))]

# %%
fold7_05 = pd.read_csv(f"/scratch1/smaruj/generate_genomic_boundary/results/target_-0.5/fold7_-0.5_genomic_windows_table_results.tsv", sep="\t")

fold7_05["fold"] = [7 for i in range(len(fold7_05))]
fold7_05["target"] = [-0.5 for i in range(len(fold7_05))]

# %%
df = pd.concat([fold0_05, fold1_05, fold2_05, fold3_05, fold4_05, fold5_05, fold6_05, fold7_05], ignore_index=True)

# %%
df["URQ_diff"] = df["URQ_result"] - df["URQ_init"]

# %%
#  fold0_alphagenome_results.tsv  fold1_alphagenome_results.tsv  fold2_alphagenome_results.tsv

# %%
alpha_fold0 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/alphagenome_CTCF_ChIPseq/fold0_alphagenome_results.tsv", sep="\t")

alpha_fold0["fold"] = [0 for i in range(len(alpha_fold0))]
# alpha_fold0["target"] = [-0.5 for i in range(len(alpha_fold0))]

# %%
alpha_fold1 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/alphagenome_CTCF_ChIPseq/fold1_alphagenome_results.tsv", sep="\t")

alpha_fold1["fold"] = [1 for i in range(len(alpha_fold1))]
# alpha_fold1["target"] = [-0.5 for i in range(len(alpha_fold1))]

# %%
alpha_fold2 = pd.read_csv(f"/scratch1/smaruj/suppressing_CTCFs/alphagenome_CTCF_ChIPseq/fold2_alphagenome_results.tsv", sep="\t")

alpha_fold2["fold"] = [2 for i in range(len(alpha_fold2))]
# alpha_fold2["target"] = [-0.5 for i in range(len(alpha_fold2))]

# %%
alpha_fold3 = pd.read_csv(f"/scratch1/smaruj/alpha_genome_validation/boundary_generation/fold3_alphagenome_results.tsv", sep="\t")

alpha_fold3["fold"] = [3 for i in range(len(alpha_fold3))]
alpha_fold3["target"] = [-0.5 for i in range(len(alpha_fold3))]

# %%
alpha_fold4 = pd.read_csv(f"/scratch1/smaruj/alpha_genome_validation/boundary_generation/fold4_alphagenome_results.tsv", sep="\t")

alpha_fold4["fold"] = [4 for i in range(len(alpha_fold4))]
alpha_fold4["target"] = [-0.5 for i in range(len(alpha_fold4))]

# %%
alpha_fold5 = pd.read_csv(f"/scratch1/smaruj/alpha_genome_validation/boundary_generation/fold5_alphagenome_results.tsv", sep="\t")

alpha_fold5["fold"] = [5 for i in range(len(alpha_fold5))]
alpha_fold5["target"] = [-0.5 for i in range(len(alpha_fold5))]

# %%
alpha_fold6 = pd.read_csv(f"/scratch1/smaruj/alpha_genome_validation/boundary_generation/fold6_alphagenome_results.tsv", sep="\t")

alpha_fold6["fold"] = [6 for i in range(len(alpha_fold6))]
alpha_fold6["target"] = [-0.5 for i in range(len(alpha_fold6))]

# %%
alpha_fold7 = pd.read_csv(f"/scratch1/smaruj/alpha_genome_validation/boundary_generation/fold7_alphagenome_results.tsv", sep="\t")

alpha_fold7["fold"] = [7 for i in range(len(alpha_fold7))]
alpha_fold7["target"] = [-0.5 for i in range(len(alpha_fold7))]

# %%
alpha_df = pd.concat([alpha_fold0, alpha_fold1, alpha_fold2], ignore_index=True)

# %%
alpha_df
# Out:
#      chrom  fold  PearsonR  centered_start  centered_end  centered_flat_start  \
# 0     chr1     0  0.861165        37799936      39110656                  192
# 1    chr11     0  0.746112        65677312      66988032                  195
# 2     chr3     0  0.670098        38524928      39835648                  144
# 3     chr3     0  0.672787        53286912      54597632                  187
# 4     chr3     0  0.676442       119885824     121196544                  154
# ..     ...   ...       ...             ...           ...                  ...
# 159   chr9     2  0.841365       101357568     102668288                  121
# 160   chr9     2  0.843037        96993280      98304000                  104
# 161   chr9     2  0.846394       112386048     113696768                  187
# 162   chr9     2  0.890602        94369792      95680512                  171
# 163   chr9     2  0.903110        99528704     100839424                  184
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df already exists
plt.figure(figsize=(6,5))

sns.boxplot(data=alpha_df[["alpha_og_CTCF_ChIPseq_sum",
                     "alpha_mod_CTCF_ChIPseq_sum"]])

plt.ylabel("CTCF ChIP-seq Sum")
plt.xlabel("")
plt.title("Original vs Modified CTCF ChIP-seq Sum")

plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
# only successful optimizations

succ_df = df[df["URQ_diff"] < 0.0].reset_index(drop=True)

# %%
succ_df[(succ_df["alpha_urq_diff"] < -0.40) & (succ_df["URQ_diff"] < -0.30)]

# %%
special_idx = [58, 8, 204]

# %%
succ_df.iloc[204]

# %%
# Assuming df and alpha_df have the same row order
x = succ_df["URQ_diff"].values
y = succ_df["alpha_urq_diff"].values

# Compute the shared limits
min_val = min(x.min(), y.min()) - 0.025
max_val = max(x.max(), y.max()) + 0.025

# Calculate Pearson correlation
pearson_r, p_value = pearsonr(x, y)
print(f"Pearson R = {pearson_r:.4f}, p-value = {p_value:.4e}")

# Scatter plot
plt.figure(figsize=(6, 6))
plt.scatter(x, y, alpha=0.6)

plt.scatter(x[special_idx], y[special_idx], color="red", s=60, label="special")

plt.xlabel("URQ diff Akita")
plt.ylabel("URQ diff Alpha Genome")
plt.title(f"Scatter plot (Pearson R = {pearson_r:.3f})")
plt.grid(True, linestyle="--", alpha=0.5)

plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)

# plt.savefig("boundary_akita_alphagenome.svg", format="svg")

plt.show()
