# %%
import pandas as pd
import numpy as np

# %%
path = "/scratch1/smaruj/stripepy_stripes/filtered_flames_results.tsv"
df = pd.read_csv(path, sep='\t')

# %%
import matplotlib.pyplot as plt

# %%
len(df)
# Out:
# 6841

# %%
df[df["flame_strength"] < -0.4]
# Out:
#      chrom1     start1       end1 chrom2     start2       end2  rel_change  \
# 14     chr1    5898240    5947392   chr1    5021696    5914624   15.261040
# 47     chr1   11583488   12836864   chr1   11575296   11608064   21.416689
# 49     chr1   11673600   11714560   chr1   11001856   11689984   24.658789
# 61     chr1   13582336   14753792   chr1   13565952   13598720   37.706806
# 205    chr1   55730176   57098240   chr1   55713792   55754752   21.436529
# ...     ...        ...        ...    ...        ...        ...         ...
# 6537   chrX   99713024   99745792   chrX   98992128   99729408   21.851480
# 6707   chrX  144367616  144416768   chrX  144138240  144400384   20.129057
# 6729   chrX  151797760  152141824   chrX  151764992  151822336   17.994877
# 6734   chrX  152879104  152903680   chrX  152371200  152879104   24.143394
# 6757   chrX  157605888  159252480   chrX  157581312  157622272   19.560016
#
# ...

# %%
plt.figure(figsize=(7, 5))
plt.hist(df["flame_strength"], bins=50, color="skyblue", edgecolor="black", alpha=0.7)
plt.xlabel("Flame Strength")
plt.ylabel("Frequency")
plt.title("Distribution of Flame Strength")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
